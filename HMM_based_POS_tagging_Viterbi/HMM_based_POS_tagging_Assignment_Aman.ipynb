# %% [markdown]
# ## POS tagging using modified Viterbi - Aman Srivastava

# %% [markdown]
# ### Data Preparation

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\amansrivasta\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
#Importing libraries
import nltk, re, pprint
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import pprint, time
import random
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# first few tagged sentences
print(nltk_data[:40])
# Out:
# [[('Pierre', 'NOUN'), ('Vinken', 'NOUN'), (',', '.'), ('61', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), (',', '.'), ('will', 'VERB'), ('join', 'VERB'), ('the', 'DET'), ('board', 'NOUN'), ('as', 'ADP'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('Nov.', 'NOUN'), ('29', 'NUM'), ('.', '.')], [('Mr.', 'NOUN'), ('Vinken', 'NOUN'), ('is', 'VERB'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Elsevier', 'NOUN'), ('N.V.', 'NOUN'), (',', '.'), ('the', 'DET'), ('Dutch', 'NOUN'), ('publishing', 'VERB'), ('group', 'NOUN'), ('.', '.')], [('Rudolph', 'NOUN'), ('Agnew', 'NOUN'), (',', '.'), ('55', 'NUM'), ('years', 'NOUN'), ('old', 'ADJ'), ('and', 'CONJ'), ('former', 'ADJ'), ('chairman', 'NOUN'), ('of', 'ADP'), ('Consolidated', 'NOUN'), ('Gold', 'NOUN'), ('Fields', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('was', 'VERB'), ('named', 'VERB'), ('*-1', 'X'), ('a', 'DET'), ('nonexecutive', 'ADJ'), ('director', 'NOUN'), ('of', 'ADP'), ('this', 'DET'), ('British', 'ADJ'), ('industrial', 'ADJ'), ('conglomerate', 'NOUN'), ('.', '.')], [('A', 'DET'), ('form', 'NOUN'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('once', 'ADV'), ('used', 'VERB'), ('*', 'X'), ('*', 'X'), ('to', 'PRT'), ('make', 'VERB'), ('Kent', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('has', 'VERB'), ('caused', 'VERB'), ('a', 'DET'), ('high', 'ADJ'), ('percentage', 'NOUN'), ('of', 'ADP'), ('cancer', 'NOUN'), ('deaths', 'NOUN'), ('among', 'ADP'), ('a', 'DET'), ('group', 'NOUN'), ('of', 'ADP'), ('workers', 'NOUN'), ('exposed', 'VERB'), ('*', 'X'), ('to', 'PRT'), ('it', 'PRON'), ('more', 'ADV'), ('than', 'ADP'), ('30', 'NUM'), ('years', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('researchers', 'NOUN'), ('reported', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('asbestos', 'NOUN'), ('fiber', 'NOUN'), (',', '.'), ('crocidolite', 'NOUN'), (',', '.'), ('is', 'VERB'), ('unusually', 'ADV'), ('resilient', 'ADJ'), ('once', 'ADP'), ('it', 'PRON'), ('enters', 'VERB'), ('the', 'DET'), ('lungs', 'NOUN'), (',', '.'), ('with', 'ADP'), ('even', 'ADV'), ('brief', 'ADJ'), ('exposures', 'NOUN'), ('to', 'PRT'), ('it', 'PRON'), ('causing', 'VERB'), ('symptoms', 'NOUN'), ('that', 'DET'), ('*T*-1', 'X'), ('show', 'VERB'), ('up', 'PRT'), ('decades', 'NOUN'), ('later', 'ADJ'), (',', '.'), ('researchers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-2', 'X'), ('.', '.')], [('Lorillard', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('the', 'DET'), ('unit', 'NOUN'), ('of', 'ADP'), ('New', 'ADJ'), ('York-based', 'ADJ'), ('Loews', 'NOUN'), ('Corp.', 'NOUN'), ('that', 'DET'), ('*T*-2', 'X'), ('makes', 'VERB'), ('Kent', 'NOUN'), ('cigarettes', 'NOUN'), (',', '.'), ('stopped', 'VERB'), ('using', 'VERB'), ('crocidolite', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('Micronite', 'NOUN'), ('cigarette', 'NOUN'), ('filters', 'NOUN'), ('in', 'ADP'), ('1956', 'NUM'), ('.', '.')], [('Although', 'ADP'), ('preliminary', 'ADJ'), ('findings', 'NOUN'), ('were', 'VERB'), ('reported', 'VERB'), ('*-2', 'X'), ('more', 'ADV'), ('than', 'ADP'), ('a', 'DET'), ('year', 'NOUN'), ('ago', 'ADP'), (',', '.'), ('the', 'DET'), ('latest', 'ADJ'), ('results', 'NOUN'), ('appear', 'VERB'), ('in', 'ADP'), ('today', 'NOUN'), ("'s", 'PRT'), ('New', 'NOUN'), ('England', 'NOUN'), ('Journal', 'NOUN'), ('of', 'ADP'), ('Medicine', 'NOUN'), (',', '.'), ('a', 'DET'), ('forum', 'NOUN'), ('likely', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('bring', 'VERB'), ('new', 'ADJ'), ('attention', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('problem', 'NOUN'), ('.', '.')], [('A', 'DET'), ('Lorillard', 'NOUN'), ('spokewoman', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('This', 'DET'), ('is', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('story', 'NOUN'), ('.', '.')], [('We', 'PRON'), ("'re", 'VERB'), ('talking', 'VERB'), ('about', 'ADP'), ('years', 'NOUN'), ('ago', 'ADP'), ('before', 'ADP'), ('anyone', 'NOUN'), ('heard', 'VERB'), ('of', 'ADP'), ('asbestos', 'NOUN'), ('having', 'VERB'), ('any', 'DET'), ('questionable', 'ADJ'), ('properties', 'NOUN'), ('.', ...

# %%
# Splitting into train and test
random.seed(1234)
train_set, test_set = train_test_split(nltk_data,test_size=0.05)

print(len(train_set))
print(len(test_set))
print(train_set[:40])
# Out:
# 3718
# 196
# [[('I', 'PRON'), ('was', 'VERB'), ('dumbfounded', 'ADJ'), (',', '.'), ("''", '.'), ('Mrs.', 'NOUN'), ('Ward', 'NOUN'), ('recalls', 'VERB'), ('*T*-1', 'X'), ('.', '.')], [('The', 'DET'), ('lower', 'ADJ'), ('figures', 'NOUN'), (',', '.'), ('the', 'DET'), ('spokesman', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), (',', '.'), ('would', 'VERB'), ('stem', 'VERB'), ('from', 'ADP'), ('preferred', 'VERB'), ('shares', 'NOUN'), ('being', 'VERB'), ('converted', 'VERB'), ('*-88', 'X'), ('to', 'PRT'), ('common', 'ADJ'), ('stock', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('possibility', 'NOUN'), ('that', 'ADP'), ('Sea', 'NOUN'), ('Containers', 'NOUN'), ("'", 'PRT'), ('subsidiaries', 'NOUN'), ('might', 'VERB'), ('be', 'VERB'), ('required', 'VERB'), ('*-2', 'X'), ('to', 'PRT'), ('place', 'VERB'), ('their', 'PRON'), ('shares', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('open', 'ADJ'), ('market', 'NOUN'), ('.', '.')], [('Other', 'ADJ'), ('financial', 'ADJ'), ('institutions', 'NOUN'), ('involved', 'VERB'), ('*', 'X'), ('include', 'VERB'), ('Barclays', 'NOUN'), ('Bank', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('Midland', 'NOUN'), ('Bank', 'NOUN'), ('PLC', 'NOUN'), (',', '.'), ('Security', 'NOUN'), ('Pacific', 'NOUN'), ('Corp.', 'NOUN'), (',', '.'), ('Chemical', 'NOUN'), ('Banking', 'NOUN'), ('Corp.', 'NOUN'), ("'s", 'PRT'), ('Chemical', 'NOUN'), ('Bank', 'NOUN'), (',', '.'), ('Citicorp', 'NOUN'), ("'s", 'PRT'), ('Citibank', 'NOUN'), ('and', 'CONJ'), ('Mitsubishi', 'NOUN'), ('Finance', 'NOUN'), ('International', 'NOUN'), ('.', '.')], [('DD', 'NOUN'), ('Acquisition', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('2.2', 'NUM'), ('million', 'NUM'), ('shares', 'NOUN'), (',', '.'), ('or', 'CONJ'), ('about', 'ADP'), ('38.5', 'NUM'), ('%', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('shares', 'NOUN'), ('outstanding', 'ADJ'), (',', '.'), ('have', 'VERB'), ('been', 'VERB'), ('tendered', 'VERB'), ('*-1', 'X'), ('under', 'ADP'), ('its', 'PRON'), ('offer', 'NOUN'), ('.', '.')], [('Stock-index', 'NOUN'), ('futures', 'NOUN'), ('--', '.'), ('Contracts', 'NOUN'), ('*', 'X'), ('to', 'PRT'), ('buy', 'VERB'), ('or', 'CONJ'), ('sell', 'VERB'), ('the', 'DET'), ('cash', 'NOUN'), ('value', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('stock', 'NOUN'), ('index', 'NOUN'), ('by', 'ADP'), ('a', 'DET'), ('certain', 'ADJ'), ('date', 'NOUN'), ('.', '.')], [('Corporate', 'ADJ'), ('lawyers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('the', 'DET'), ('new', 'ADJ'), ('fees', 'NOUN'), ('would', 'VERB'), ("n't", 'ADV'), ('inhibit', 'VERB'), ('many', 'ADJ'), ('mergers', 'NOUN'), ('or', 'CONJ'), ('other', 'ADJ'), ('transactions', 'NOUN'), ('.', '.')], [('Because', 'ADP'), ('of', 'ADP'), ('budget', 'NOUN'), ('constraints', 'NOUN'), ('in', 'ADP'), ('Washington', 'NOUN'), (',', '.'), ('the', 'DET'), ('U.S.', 'NOUN'), ('encourages', 'VERB'), ('Japan', 'NOUN'), ('to', 'PRT'), ('share', 'VERB'), ('economic', 'ADJ'), ('burdens', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('region', 'NOUN'), ('.', '.')], [('At', 'ADP'), ('one', 'NUM'), ('point', 'NOUN'), (',', '.'), ('Mr.', 'NOUN'), ('Phelan', 'NOUN'), ('angered', 'VERB'), ('the', 'DET'), ('subcommittee', 'NOUN'), ("'s", 'PRT'), ('chairman', 'NOUN'), (',', '.'), ('Rep.', 'NOUN'), ('Edward', 'NOUN'), ('Markey', 'NOUN'), ('-LRB-', '.'), ('D.', 'NOUN'), (',', '.'), ('Mass.', 'NOUN'), ('-RRB-', '.'), (',', '.'), ('by', 'ADP'), ('*-2', 'X'), ('not', 'ADV'), ('going', 'VERB'), ('much', 'ADV'), ('beyond', 'ADP'), ('what', 'PRON'), ('*T*-1', 'X'), ('already', 'ADV'), ('had', 'VERB'), ('been', 'VERB'), ('reported', 'VERB'), ('*-131', 'X'), ('in', 'ADP'), ('the', 'DET'), ('morning', 'NOUN'), ('newspapers', 'NOUN'), ('.', '.')], [('Under', 'ADP'), ('an', 'DET'), ('accord', 'NOUN'), ('signed', 'VERB'), ('*', 'X'), ('yesterday', 'NOUN'), (',', '.'), ('the', 'DET'), ('government', 'NOUN'), ('and', 'CONJ'), ('Union', 'NOUN'), ('Bank', 'NOUN'), ('of', 'ADP'), ('Finland', 'NOUN'), ('would', 'VERB'), ('become', 'VERB'), ('major', 'ADJ'), ('shareholders', 'NOUN'), ('in', 'ADP ...

# %%
# Getting list of tagged words
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)
# Out:
# 95713

# %%
# tokens 
tokens = [pair[0] for pair in train_tagged_words]
tokens[:10]
# Out:
# ['I', 'was', 'dumbfounded', ',', "''", 'Mrs.', 'Ward', 'recalls', '*T*-1', '.']

# %%
# vocabulary
V = set(tokens)
print(len(V))
# Out:
# 12117

# %%
# number of tags
T = set([pair[1] for pair in train_tagged_words])
len(T)
# Out:
# 12

# %%
print(T)
# Out:
# {'ADJ', 'CONJ', 'NOUN', 'VERB', 'NUM', '.', 'ADV', 'ADP', 'X', 'PRT', 'DET', 'PRON'}

# %% [markdown]
# ### Emission Probabilities

# %%
# computing P(w/t) and storing in T x V matrix
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %% [markdown]
# ### Transition Probabilities

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
# convert the matrix to a df for better readability
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))

# %%
tags_df.head()
# Out:
#            ADJ      CONJ      NOUN      VERB       NUM         .       ADV  \
# ADJ   0.066249  0.016974  0.698253  0.012030  0.021589  0.064436  0.004450
# CONJ  0.119555  0.000463  0.352178  0.156163  0.041242  0.035218  0.052363
# NOUN  0.012209  0.042567  0.263530  0.147017  0.009585  0.239805  0.017165
# VERB  0.065368  0.005279  0.110628  0.168388  0.023135  0.035090  0.081515
# NUM   0.033245  0.014122  0.350986  0.018241  0.185349  0.117976  0.002648
#
#            ADP         X       PRT       DET      PRON
# ADJ   0.079103  0.020765  0.010547  0.004944  0.000659
# CONJ  0.051900  0.008341  0.005097  0.120019  0.057461
# NOUN  0.177776  0.028536  0.044098  0.012938  0.004774
# VERB  0.091530  0.218694  0.031364  0.133918  0.035090
# NUM   0.034716  0.210062  0.027655  0.003530  0.001471

# %%
len(train_tagged_words)
# Out:
# 95713

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# ####  Evaluating on Test Set for Viterbi

# %%
# list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]

# list of untagged words
test_tagged_words = [tup[0] for sent in test_set for tup in sent]
test_set
# Out:
# [[('Mr.', 'NOUN'),
#   ('Trump', 'NOUN'),
#   ('withdrew', 'VERB'),
#   ('a', 'DET'),
#   ('$', '.'),
#   ('120-a-share', 'ADJ'),
#   ('*U*', 'X'),
#   ('bid', 'NOUN'),
#   ('last', 'ADJ'),
#   ('month', 'NOUN'),
#   ('.', '.')],
#  [('Japan', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Finance', 'NOUN'),
#   ('Ministry', 'NOUN'),
#   ('had', 'VERB'),
#   ('set', 'VERB'),
#   ('up', 'PRT'),
#   ('mechanisms', 'NOUN'),
#   ('0', 'X'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('limit', 'VERB'),
#   ('how', 'ADV'),
#   ('far', 'ADJ'),
#   ('futures', 'NOUN'),
#   ('prices', 'NOUN'),
#   ('could', 'VERB'),
#   ('fall', 'VERB'),
#   ('*T*-2', 'X'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('single', 'ADJ'),
#   ('session', 'NOUN'),
#   ('and', 'CONJ'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('give', 'VERB'),
#   ('market', 'NOUN'),
#   ('operators', 'NOUN'),
#   ('the', 'DET'),
#   ('authority', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('suspend', 'VERB'),
#   ('trading', 'NOUN'),
#   ('in', 'ADP'),
#   ('futures', 'NOUN'),
#   ('at', 'ADP'),
#   ('any', 'DET'),
#   ('time', 'NOUN'),
#   ('.', '.')],
#  [('I', 'PRON'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('right', 'NOUN'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('print', 'VERB'),
#   ('those', 'DET'),
#   ('scripts', 'NOUN'),
#   ('if', 'ADP'),
#   ('I', 'PRON'),
#   ('go', 'VERB'),
#   ('there', 'ADV'),
#   ('and', 'CONJ'),
#   ('laboriously', 'ADV'),
#   ('--', '.'),
#   ('but', 'CONJ'),
#   ('no', 'ADV'),
#   ('longer', 'ADJ'),
#   ('surreptitiously', 'ADV'),
#   ('--', '.'),
#   ('copy', 'VERB'),
#   ('them', 'PRON'),
#   ('out', 'PRT'),
#   ('in', 'ADP'),
#   ('long', 'ADJ'),
#   ('hand', 'NOUN'),
#   ('.', '.')],
#  [('*', 'X'),
#   ('Take', 'VERB'),
#   ('Lake', 'NOUN'),
#   ('Vineyard', 'NOUN'),
#   ('Cabernet', 'NOUN'),
#   ('from', 'ADP'),
#   ('Diamond', 'NOUN'),
#   ('Creek', 'NOUN'),
#   ('.', '.')],
#  [('And', 'CONJ'),
#   ('unlike', 'ADP'),
#   ('some', 'DET'),
#   ('trays', 'NOUN'),
#   (',', '.'),
#   ('there', 'DET'),
#   ("'s", 'VERB'),
#   ('no', 'DET'),
#   ('place', 'NOUN'),
#   ('for', 'ADP'),
#   ('food', 'NOUN'),
#   ('.', '.')],
#  [('Standard', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Poor', 'NOUN'),
#   ("'s", 'PRT'),
#   ('Corp.', 'NOUN'),
#   ('says', 'VERB'),
#   ('0', 'X'),
#   ('First', 'NOUN'),
#   ('Boston', 'NOUN'),
#   (',', '.'),
#   ('Shearson', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Drexel', 'NOUN'),
#   ('Burnham', 'NOUN'),
#   ('Lambert', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('particular', 'ADJ'),
#   (',', '.'),
#   ('are', 'VERB'),
#   ('likely', 'ADJ'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('have', 'VERB'),
#   ('difficulty', 'NOUN'),
#   ('*-2', 'X'),
#   ('shoring', 'VERB'),
#   ('up', 'PRT'),
#   ('their', 'PRON'),
#   ('credit', 'NOUN'),
#   ('standing', 'NOUN'),
#   ('in', 'ADP'),
#   ('months', 'NOUN'),
#   ('ahead', 'ADV'),
#   ('.', '.')],
#  [('Also', 'ADV'),
#   (',', '.'),
#   ('Big', 'NOUN'),
#   ('Board', 'NOUN'),
#   ('Chairman', 'NOUN'),
#   ('Phelan', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('he', 'PRON'),
#   ('would', 'VERB'),
#   ('support', 'VERB'),
#   ('SEC', 'NOUN'),
#   ('halts', 'NOUN'),
#   ('of', 'ADP'),
#   ('program', 'NOUN'),
#   ('trading', 'NOUN'),
#   ('during', 'ADP'),
#   ('market', 'NOUN'),
#   ('crises', 'NOUN'),
#   ('but', 'CONJ'),
#   ('not', 'ADV'),
#   ('any', 'DET'),
#   ('revival', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('``', '.'),
#   ('collar', 'NOUN'),
#   ("''", '.'),
#   ('on', 'ADP'),
#   ('trading', 'NOUN'),
#   ('.', '.')],
#  [('Columbia', 'NOUN'),
#   ('Savings', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Loan', 'NOUN'),
#   ('-LRB-', '.'),
#   ('NYSE', 'NOUN'),
#   (';', '.'),
#   ('Symbol', 'NOUN'),
#   (':', '.'),
#   ('CSV', 'NOUN'),
#   ('-RRB-', '.')],
#  [('I', 'PRON'),
#   ('say', 'VERB'),
#   ('``', '.'),
#   ('*', 'X'),
#   ('contained', 'VERB'),
#   ('dialogue', 'NOUN'),
#   ("''", '.'),
#   ('because', 'ADP'),
#   ('``', '.'),
#   ('Sidewalk', 'NOUN'),
#   ('Stories', 'NOUN'),
#   ("''", '.'),
#   ('is', 'VERB'),
#   ("n't", 'ADV'),
#   ('really', 'ADV'),
#   ('silent', 'ADJ'),
#   ('at', 'ADP'),
#   ('all', 'DET'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('his', 'PRON'),
#   ('return', 'NOUN'),
#   ('toast', 'NOUN'),
#   ('to', 'PRT'),
#   ('Mr.', 'NOUN'),
#   ('Nixon', 'NOUN'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Yang', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('relationship', 'NOUN'),
#   ('had', 'VERB'),
#   ('reached', 'VERB'),
#   ('a', 'DET'),
#   ('``', '.'),
#   ('stalemate', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Municipal', 'ADJ'),
#   ('bonds', 'NOUN'),
#   ('were', 'VERB'),
#   ('mostly', 'ADV'),
#   ('unchanged', 'ADJ'),
#   ('to', 'PRT'),
#   ('up', 'ADV'),
#   ('1\\/8', 'NUM'),
#   ('point', 'NOUN'),
#   ('in', 'ADP'),
#   ('light', 'ADJ'),
#   (',', '.'),
#   ('cautious', 'ADJ'),
#   ('trading', 'NOUN'),
#   ('prior', 'ADV'),
#   ('to', 'PRT'),
#   ('tomorrow', 'NOUN'),
#   ("'s", 'PRT'),
#   ('unemployment', 'NOUN'),
#   ('report', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Transportation', 'NOUN'),
#   ('Department', 'NOUN'),
#   (',', '.'),
#   ('*-1', 'X'),
#   ('responding', 'VERB'),
#   ('to', 'PRT'),
#   ('pressure', 'NOUN'),
#   ('from', 'ADP'),
#   ('safety', 'NOUN'),
#   ('advocates', 'NOUN'),
#   (',', '.'),
#   ('took', 'VERB'),
#   ('further', 'ADJ'),
#   ('steps', 'NOUN'),
#   ('0', 'X'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('impose', 'VERB'),
#   ('on', 'ADP'),
#   ('light', 'ADJ'),
#   ('trucks', 'NOUN'),
#   ('and', 'CONJ'),
#   ('vans', 'NOUN'),
#   ('the', 'DET'),
#   ('safety', 'NOUN'),
#   ('requirements', 'NOUN'),
#   ('used', 'VERB'),
#   ('*', 'X'),
#   ('for', 'ADP'),
#   ('automobiles', 'NOUN'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('``', '.'),
#   ('The', 'DET'),
#   ('thing', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('will', 'VERB'),
#   ('really', 'ADV'),
#   ('break', 'VERB'),
#   ('this', 'DET'),
#   ('market', 'NOUN'),
#   ('right', 'ADV'),
#   ('open', 'ADJ'),
#   ('is', 'VERB'),
#   ('merchandising', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('Ms.', 'NOUN'),
#   ('West', 'NOUN'),
#   ('says', 'VERB'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('While', 'ADP'),
#   ('researchers', 'NOUN'),
#   ('believe', 'VERB'),
#   ('0', 'X'),
#   ('such', 'ADJ'),
#   ('transplants', 'NOUN'),
#   ('could', 'VERB'),
#   ('help', 'VERB'),
#   ('*-1', 'X'),
#   ('treat', 'VERB'),
#   ('diseases', 'NOUN'),
#   ('like', 'ADP'),
#   ('Alzheimer', 'NOUN'),
#   ("'s", 'PRT'),
#   (',', '.'),
#   ('anti-abortionists', 'NOUN'),
#   ('oppose', 'VERB'),
#   ('the', 'DET'),
#   ('research', 'NOUN'),
#   ('.', '.')],
#  [('E.', 'NOUN'),
#   ('Guigal', 'NOUN'),
#   ("'s", 'PRT'),
#   ('1982', 'NUM'),
#   ('Cote', 'NOUN'),
#   ('Rotie', 'NOUN'),
#   ('La', 'NOUN'),
#   ('Landonne', 'NOUN'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('example', 'NOUN'),
#   (',', '.'),
#   ('is', 'VERB'),
#   ('$', '.'),
#   ('120', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('Their', 'PRON'),
#   ('books', 'NOUN'),
#   ('are', 'VERB'),
#   ('written', 'VERB'),
#   ('*-1', 'X'),
#   ('in', 'ADP'),
#   ('idiomatic', 'ADJ'),
#   (',', '.'),
#   ('contemporary', 'ADJ'),
#   ('language', 'NOUN'),
#   ('and', 'CONJ'),
#   ('usually', 'ADV'),
#   ('carry', 'VERB'),
#   ('hefty', 'ADJ'),
#   ('dashes', 'NOUN'),
#   ('of', 'ADP'),
#   ('Americana', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('filing', 'NOUN'),
#   ('adds', 'VERB'),
#   ('a', 'DET'),
#   ('new', 'ADJ'),
#   ('twist', 'NOUN'),
#   ('to', 'PRT'),
#   ('market', 'NOUN'),
#   ('speculation', 'NOUN'),
#   ('that', 'ADP'),
#   ('Coniston', 'NOUN'),
#   ('Partners', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('money', 'NOUN'),
#   ('manager', 'NOUN'),
#   (',', '.'),
#   ('has', 'VERB'),
#   ('bought', 'VERB'),
#   ('more', 'ADJ'),
#   ('than', 'ADP'),
#   ('5', 'NUM'),
#   ('%', 'NOUN'),
#   ('of', 'ADP'),
#   ('UAL', 'NOUN'),
#   ('stock', 'NOUN'),
#   ('and', 'CONJ'),
#   ('may', 'VERB'),
#   ('challenge', 'VERB'),
#   ('the', 'DET'),
#   ('UAL', 'NOUN'),
#   ('board', 'NOUN'),
#   ("'s", 'PRT'),
#   ('decision', 'NOUN'),
#   ('*ICH*-1', 'X'),
#   ('last', 'ADJ'),
#   ('week', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('remain', 'VERB'),
#   ('independent', 'ADJ'),
#   ('.', '.')],
#  [('Among', 'ADP'),
#   ('other', 'ADJ'),
#   ('things', 'NOUN'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('included', 'VERB'),
#   ('checking', 'VERB'),
#   (',', '.'),
#   ('safe', 'ADJ'),
#   ('deposit', 'NOUN'),
#   ('box', 'NOUN'),
#   ('and', 'CONJ'),
#   ('credit', 'NOUN'),
#   ('card', 'NOUN'),
#   ('--', '.'),
#   ('all', 'DET'),
#   ('for', 'ADP'),
#   ('free', 'ADJ'),
#   ('--', '.'),
#   ('plus', 'ADV'),
#   ('a', 'DET'),
#   ('good', 'ADJ'),
#   ('deal', 'NOUN'),
#   ('on', 'ADP'),
#   ('installment', 'NOUN'),
#   ('loans', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('She', 'PRON'),
#   ('was', 'VERB'),
#   ('an', 'DET'),
#   ('inspirational', 'ADJ'),
#   ('lady', 'NOUN'),
#   (';', '.'),
#   ('she', 'PRON'),
#   ('had', 'VERB'),
#   ('it', 'PRON'),
#   ('all', 'ADV'),
#   ('together', 'ADV'),
#   (',', '.'),
#   ("''", '.'),
#   ('says', 'VERB'),
#   ('*T*-1', 'X'),
#   ('Laura', 'NOUN'),
#   ('Dobson', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('freshman', 'NOUN'),
#   ('at', 'ADP'),
#   ('the', 'DET'),
#   ('University', 'NOUN'),
#   ('of', 'ADP'),
#   ('South', 'NOUN'),
#   ('Carolina', 'NOUN'),
#   ('who', 'PRON'),
#   ('*T*-90', 'X'),
#   ('had', 'VERB'),
#   ('Mrs.', 'NOUN'),
#   ('Yeargin', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('teacher-cadet', 'ADJ'),
#   ('class', 'NOUN'),
#   ('last', 'ADJ'),
#   ('year', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('program', 'NOUN'),
#   (',', '.'),
#   ('available', 'ADJ'),
#   ('to', 'PRT'),
#   ('Upjohn', 'NOUN'),
#   ('employees', 'NOUN'),
#   ('55', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   ('or', 'CONJ'),
#   ('older', 'ADJ'),
#   (',', '.'),
#   ('could', 'VERB'),
#   ('increase', 'VERB'),
#   ('an', 'DET'),
#   ('individual', 'NOUN'),
#   ("'s", 'PRT'),
#   ('retirement', 'NOUN'),
#   ('benefits', 'NOUN'),
#   ('10', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PRT'),
#   ('20', 'NUM'),
#   ('%', 'NOUN'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('``', '.'),
#   ('An', 'DET'),
#   ('active', 'ADJ'),
#   ('55-year-old', 'NOUN'),
#   ('in', 'ADP'),
#   ('Boca', 'NOUN'),
#   ('Raton', 'NOUN'),
#   ('may', 'VERB'),
#   ('care', 'VERB'),
#   ('more', 'ADV'),
#   ('about', 'ADP'),
#   ('Senior', 'NOUN'),
#   ('Olympic', 'NOUN'),
#   ('games', 'NOUN'),
#   (',', '.'),
#   ('while', 'ADP'),
#   ('a', 'DET'),
#   ('75-year-old', 'NUM'),
#   ('in', 'ADP'),
#   ('Panama', 'NOUN'),
#   ('City', 'NOUN'),
#   ('may', 'VERB'),
#   ('care', 'VERB'),
#   ('more', 'ADV'),
#   ('about', 'ADP'),
#   ('a', 'DET'),
#   ('seminar', 'NOUN'),
#   ('on', 'ADP'),
#   ('health', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('she', 'PRON'),
#   ('says', 'VERB'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('``', '.'),
#   ('The', 'DET'),
#   ('way', 'NOUN'),
#   ('that', 'ADP'),
#   ('we', 'PRON'),
#   ("'ve", 'VERB'),
#   ('been', 'VERB'),
#   ('managing', 'VERB'),
#   ('Campbell', 'NOUN'),
#   ('U.S.A.', 'NOUN'),
#   ('*T*-2', 'X'),
#   ('can', 'VERB'),
#   ('hopefully', 'ADV'),
#   ('spread', 'VERB'),
#   ('to', 'PRT'),
#   ('other', 'ADJ'),
#   ('areas', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('Mr.', 'NOUN'),
#   ('Baum', 'NOUN'),
#   ('said', 'VERB'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('NL', 'NOUN'),
#   ('is', 'VERB'),
#   ('officially', 'ADV'),
#   ('making', 'VERB'),
#   ('the', 'DET'),
#   ('offer', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Oxnard', 'NOUN'),
#   ('observed', 'VERB'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('situation', 'NOUN'),
#   ('in', 'ADP'),
#   ('Brazil', 'NOUN'),
#   ('is', 'VERB'),
#   ('also', 'ADV'),
#   ('very', 'ADV'),
#   ('complicated', 'VERB'),
#   ('.', '.')],
#  [('``', '.'),
#   ('It', 'PRON'),
#   ('can', 'VERB'),
#   ('be', 'VERB'),
#   ('said', 'VERB'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('trend', 'NOUN'),
#   ('of', 'ADP'),
#   ('financial', 'ADJ'),
#   ('improvement', 'NOUN'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('firmly', 'ADV'),
#   ('set', 'VERB'),
#   (',', '.'),
#   ("''", '.'),
#   ('he', 'PRON'),
#   ('added', 'VERB'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('South', 'NOUN'),
#   ('Korea', 'NOUN'),
#   ('has', 'VERB'),
#   ('different', 'ADJ'),
#   ('concerns', 'NOUN'),
#   ('.', '.')],
#  [('For', 'ADP'),
#   ('an', 'DET'),
#   ('American', 'ADJ'),
#   ('reader', 'NOUN'),
#   (',', '.'),
#   ('part', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('charm', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('engaging', 'ADJ'),
#   ('novel', 'NOUN'),
#   ('should', 'VERB'),
#   ('come', 'VERB'),
#   ('in', 'ADP'),
#   ('*', 'X'),
#   ('recognizing', 'VERB'),
#   ('that', 'ADP'),
#   ('Japan', 'NOUN'),
#   ('is', 'VERB'),
#   ("n't", 'ADV'),
#   ('the', 'DET'),
#   ('buttoned-down', 'ADJ'),
#   ('society', 'NOUN'),
#   ('of', 'ADP'),
#   ('contemporary', 'ADJ'),
#   ('American', 'ADJ'),
#   ('lore', 'NOUN'),
#   ('.', '.')],
#  [('*', 'X'),
#   ('Put', 'VERB'),
#   ('*-1', 'X'),
#   ('another', 'DET'),
#   ('way', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('decline', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('yield', 'NOUN'),
#   ('suggests', 'VERB'),
#   ('0', 'X'),
#   ('stocks', 'NOUN'),
#   ('have', 'VERB'),
#   ('gotten', 'VERB'),
#   ('pretty', 'ADV'),
#   ('rich', 'ADJ'),
#   ('in', 'ADP'),
#   ('price', 'NOUN'),
#   ('relative', 'ADJ'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('dividends', 'NOUN'),
#   ('0', 'X'),
#   ('they', 'PRON'),
#   ('pay', 'VERB'),
#   ('*T*-2', 'X'),
#   (',', '.'),
#   ('some', 'DET'),
#   ('market', 'NOUN'),
#   ('analysts', 'NOUN'),
#   ('say', 'VERB'),
#   ('0', 'X'),
#   ('*T*-3', 'X'),
#   ('.', '.')],
#  [('``', '.'),
#   ('So', 'ADV'),
#   ('efforts', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('beat', 'VERB'),
#   ('the', 'DET'),
#   ('tests', 'NOUN'),
#   ('are', 'VERB'),
#   ('also', 'ADV'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('rise', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Department', 'NOUN'),
#   ('officials', 'NOUN'),
#   ('say', 'VERB'),
#   ('that', 'ADP'),
#   ('HHS', 'NOUN'),
#   ('Secretary', 'NOUN'),
#   ('Louis', 'NOUN'),
#   ('Sullivan', 'NOUN'),
#   ('will', 'VERB'),
#   ('support', 'VERB'),
#   ('Dr.', 'NOUN'),
#   ('Mason', 'NOUN'),
#   ("'s", 'PRT'),
#   ('ruling', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-112', 'X'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('issued', 'VERB'),
#   ('*-1', 'X'),
#   ('soon', 'ADV'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('form', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('letter', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('acting', 'ADJ'),
#   ('director', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('National', 'NOUN'),
#   ('Institutes', 'NOUN'),
#   ('of', 'ADP'),
#   ('Health', 'NOUN'),
#   ('.', '.')],
#  [('Bank', 'NOUN'),
#   ('of', 'ADP'),
#   ('New', 'NOUN'),
#   ('England', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('has', 'VERB'),
#   ('held', 'VERB'),
#   ('talks', 'NOUN'),
#   ('with', 'ADP'),
#   ('potential', 'ADJ'),
#   ('merger', 'NOUN'),
#   ('partners', 'NOUN'),
#   ('outside', 'ADP'),
#   ('New', 'NOUN'),
#   ('England', 'NOUN'),
#   (',', '.'),
#   ('although', 'ADP'),
#   ('it', 'PRON'),
#   ('added', 'VERB'),
#   ('that', 'ADP'),
#   ('nothing', 'NOUN'),
#   ('is', 'VERB'),
#   ('imminent', 'ADJ'),
#   ('and', 'CONJ'),
#   ('it', 'PRON'),
#   ('has', 'VERB'),
#   ("n't", 'ADV'),
#   ('received', 'VERB'),
#   ('any', 'DET'),
#   ('formal', 'ADJ'),
#   ('offers', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('industrial', 'ADJ'),
#   ('average', 'NOUN'),
#   ('jumped', 'VERB'),
#   ('more', 'ADV'),
#   ('than', 'ADP'),
#   ('41', 'NUM'),
#   ('points', 'NOUN'),
#   ('Tuesday', 'NOUN'),
#   ('as', 'ADP'),
#   ('speculators', 'NOUN'),
#   ('rushed', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('buy', 'VERB'),
#   ('shares', 'NOUN'),
#   ('of', 'ADP'),
#   ('potential', 'ADJ'),
#   ('takeover', 'NOUN'),
#   ('targets', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('question', 'NOUN'),
#   ('now', 'ADV'),
#   (':', '.'),
#   ('Can', 'VERB'),
#   ('he', 'PRON'),
#   ('act', 'VERB'),
#   ('more', 'ADV'),
#   ('like', 'ADP'),
#   ('hard-charging', 'ADJ'),
#   ('Teddy', 'NOUN'),
#   ('Roosevelt', 'NOUN'),
#   ('?', '.')],
#  [('In', 'ADP'),
#   ('any', 'DET'),
#   ('case', 'NOUN'),
#   (',', '.'),
#   ('opinion', 'NOUN'),
#   ('*ICH*-2', 'X'),
#   ('is', 'VERB'),
#   ('mixed', 'VERB'),
#   ('on', 'ADP'),
#   ('how', 'ADV'),
#   ('much', 'ADJ'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('boost', 'NOUN'),
#   ('the', 'DET'),
#   ('overall', 'ADJ'),
#   ('stock', 'NOUN'),
#   ('market', 'NOUN'),
#   ('would', 'VERB'),
#   ('get', 'VERB'),
#   ('*T*-1', 'X'),
#   ('even', 'ADV'),
#   ('if', 'ADP'),
#   ('dividend', 'NOUN'),
#   ('growth', 'NOUN'),
#   ('continues', 'VERB'),
#   ('at', 'ADP'),
#   ('double-digit', 'ADJ'),
#   ('levels', 'NOUN'),
#   ('.', '.')],
#  [('It', 'PRON'),
#   ('does', 'VERB'),
#   ('a', 'DET'),
#   ('first-rate', 'ADJ'),
#   ('job', 'NOUN'),
#   ('.', '.')],
#  [('--', '.'),
#   ('The', 'DET'),
#   ('USIA', 'NOUN'),
#   ('said', 'VERB'),
#   ('that', 'ADP'),
#   (',', '.'),
#   ('on', 'ADP'),
#   ('reflection', 'NOUN'),
#   (',', '.'),
#   ('of', 'ADP'),
#   ('course', 'NOUN'),
#   ('I', 'PRON'),
#   ('could', 'VERB'),
#   ('print', 'VERB'),
#   ('anything', 'NOUN'),
#   ('0', 'X'),
#   ('I', 'PRON'),
#   ('could', 'VERB'),
#   ('get', 'VERB'),
#   ('my', 'PRON'),
#   ('hands', 'NOUN'),
#   ('on', 'ADP'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('Prosecutors', 'NOUN'),
#   ('alleged', 'VERB'),
#   ('that', 'ADP'),
#   ('she', 'PRON'),
#   ('was', 'VERB'),
#   ('trying', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('bolster', 'VERB'),
#   ('students', 'NOUN'),
#   ("'", 'PRT'),
#   ('scores', 'NOUN'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('win', 'VERB'),
#   ('a', 'DET'),
#   ('bonus', 'NOUN'),
#   ('under', 'ADP'),
#   ('the', 'DET'),
#   ('state', 'NOUN'),
#   ("'s", 'PRT'),
#   ('1984', 'NUM'),
#   ('Education', 'NOUN'),
#   ('Improvement', 'NOUN'),
#   ('Act', 'NOUN'),
#   ('.', '.')],
#  [('Esso', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('fields', 'NOUN'),
#   ('were', 'VERB'),
#   ('developed', 'VERB'),
#   ('*-36', 'X'),
#   ('after', 'ADP'),
#   ('the', 'DET'),
#   ('Australian', 'ADJ'),
#   ('government', 'NOUN'),
#   ('decided', 'VERB'),
#   ('in', 'ADP'),
#   ('1987', 'NUM'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('make', 'VERB'),
#   ('the', 'DET'),
#   ('first', 'ADJ'),
#   ('30', 'NUM'),
#   ('million', 'NUM'),
#   ('barrels', 'NOUN'),
#   ('from', 'ADP'),
#   ('new', 'ADJ'),
#   ('fields', 'NOUN'),
#   ('free', 'ADJ'),
#   ('of', 'ADP'),
#   ('excise', 'ADJ'),
#   ('tax', 'NOUN'),
#   ('.', '.')],
#  [('Carnival', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-1', 'X'),
#   ('has', 'VERB'),
#   ('three', 'NUM'),
#   ('ships', 'NOUN'),
#   ('on', 'ADP'),
#   ('order', 'NOUN'),
#   ('from', 'ADP'),
#   ('Waertsilae', 'NOUN'),
#   ('Marine', 'NOUN'),
#   (',', '.'),
#   ('presented', 'VERB'),
#   ('claims', 'NOUN'),
#   ('for', 'ADP'),
#   ('$', '.'),
#   ('1.5', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   ('damages', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('bankruptcy', 'NOUN'),
#   ('court', 'NOUN'),
#   ('this', 'DET'),
#   ('week', 'NOUN'),
#   ('.', '.')],
#  [('Norman', 'NOUN'),
#   ('Ricken', 'NOUN'),
#   (',', '.'),
#   ('52', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   ('and', 'CONJ'),
#   ('former', 'ADJ'),
#   ('president', 'NOUN'),
#   ('and', 'CONJ'),
#   ('chief', 'NOUN'),
#   ('operating', 'VERB'),
#   ('officer', 'NOUN'),
#   ('of', 'ADP'),
#   ('Toys', 'NOUN'),
#   ('``', '.'),
#   ('R', 'NOUN'),
#   ("''", '.'),
#   ('Us', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('Frederick', 'NOUN'),
#   ('Deane', 'NOUN'),
#   ('Jr.', 'NOUN'),
#   (',', '.'),
#   ('63', 'NUM'),
#   (',', '.'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Signet', 'NOUN'),
#   ('Banking', 'NOUN'),
#   ('Corp.', 'NOUN'),
#   (',', '.'),
#   ('were', 'VERB'),
#   ('elected', 'VERB'),
#   ('*-15', 'X'),
#   ('directors', 'NOUN'),
#   ('of', 'ADP'),
#   ('this', 'DET'),
#   ('consumer', 'NOUN'),
#   ('electronics', 'NOUN'),
#   ('and', 'CONJ'),
#   ('appliances', 'NOUN'),
#   ('retailing', 'NOUN'),
#   ('chain', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('voters', 'NOUN'),
#   ('decided', 'VERB'),
#   ('that', 'ADP'),
#   ('if', 'ADP'),
#   ('the', 'DET'),
#   ('stadium', 'NOUN'),
#   ('was', 'VERB'),
#   ('such', 'DET'),
#   ('a', 'DET'),
#   ('good', 'ADJ'),
#   ('idea', 'NOUN'),
#   ('someone', 'NOUN'),
#   ('would', 'VERB'),
#   ('build', 'VERB'),
#   ('it', 'PRON'),
#   ('himself', 'PRON'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('rejected', 'VERB'),
#   ('it', 'PRON'),
#   ('59', 'NUM'),
#   ('%', 'NOUN'),
#   ('to', 'PRT'),
#   ('41', 'NUM'),
#   ('%', 'NOUN'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('Now', 'ADV'),
#   (',', '.'),
#   ('only', 'ADV'),
#   ('one', 'NUM'),
#   ('local', 'ADJ'),
#   ('ringer', 'NOUN'),
#   ('*ICH*-1', 'X'),
#   ('remains', 'VERB'),
#   (':', '.'),
#   ('64-year-old', 'ADJ'),
#   ('Derek', 'NOUN'),
#   ('Hammond', 'NOUN'),
#   ('.', '.')],
#  [('Producers', 'NOUN'),
#   ('have', 'VERB'),
#   ('seen', 'VERB'),
#   ('this', 'DET'),
#   ('market', 'NOUN'),
#   ('opening', 'VERB'),
#   ('up', 'PRT'),
#   ('and', 'CONJ'),
#   ('they', 'PRON'),
#   ("'re", 'VERB'),
#   ('now', 'ADV'),
#   ('creating', 'VERB'),
#   ('wines', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-168', 'X'),
#   ('appeal', 'VERB'),
#   ('to', 'PRT'),
#   ('these', 'DET'),
#   ('people', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Virginia', 'NOUN'), (':', '.')],
#  [('Gilts', 'NOUN'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('British', 'ADJ'),
#   ('government', 'NOUN'),
#   ('bonds', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-60', 'X'),
#   ('also', 'ADV'),
#   ('fell', 'VERB'),
#   ('sharply', 'ADV'),
#   ('initially', 'ADV'),
#   (',', '.'),
#   ('retraced', 'VERB'),
#   ('some', 'DET'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('losses', 'NOUN'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('end', 'VERB'),
#   ('about', 'ADP'),
#   ('3\\/8', 'NUM'),
#   ('point', 'NOUN'),
#   ('lower', 'ADJ'),
#   ('.', '.')],
#  [('J.P.', 'NOUN'),
#   ('Bolduc', 'NOUN'),
#   (',', '.'),
#   ('vice', 'NOUN'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('W.R.', 'NOUN'),
#   ('Grace', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Co.', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-10', 'X'),
#   ('holds', 'VERB'),
#   ('a', 'DET'),
#   ('83.4', 'NUM'),
#   ('%', 'NOUN'),
#   ('interest', 'NOUN'),
#   ('in', 'ADP'),
#   ('this', 'DET'),
#   ('energy-services', 'ADJ'),
#   ('company', 'NOUN'),
#   (',', '.'),
#   ('was', 'VERB'),
#   ('elected', 'VERB'),
#   ('*-10', 'X'),
#   ('a', 'DET'),
#   ('director', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('he', 'PRON'),
#   ('has', 'VERB'),
#   ('not', 'ADV'),
#   ('said', 'VERB'),
#   ('before', 'ADP'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('country', 'NOUN'),
#   ('wants', 'VERB'),
#   ('half', 'DET'),
#   ('the', 'DET'),
#   ('debt', 'NOUN'),
#   ('forgiven', 'VERB'),
#   ('*-2', 'X'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('following', 'VERB'),
#   ('individuals', 'NOUN'),
#   ('were', 'VERB'),
#   ('fined', 'VERB'),
#   ('*-2', 'X'),
#   ('as', 'ADP'),
#   ('*', 'X'),
#   ('indicated', 'VERB'),
#   ('*-1', 'X'),
#   ('and', 'CONJ'),
#   ('barred', 'VERB'),
#   ('*-2', 'X'),
#   ('from', 'ADP'),
#   ('association', 'NOUN'),
#   ('with', 'ADP'),
#   ('NASD', 'NOUN'),
#   ('members', 'NOUN'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   (',', '.'),
#   ('where', 'ADV'),
#   ('*', 'X'),
#   ('noted', 'VERB'),
#   ('*-3', 'X'),
#   ('*T*-4', 'X'),
#   (',', '.'),
#   ('suspended', 'VERB'),
#   ('*-2', 'X'),
#   ('.', '.')],
#  [('Young', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Rubicam', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('completed', 'VERB'),
#   ('its', 'PRON'),
#   ('acquisition', 'NOUN'),
#   ('of', 'ADP'),
#   ('Landor', 'NOUN'),
#   ('Associates', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('San', 'NOUN'),
#   ('Francisco', 'NOUN'),
#   ('identity-management', 'NOUN'),
#   ('firm', 'NOUN'),
#   ('.', '.')],
#  [('Yet', 'ADV'),
#   ('this', 'DET'),
#   ('woman', 'NOUN'),
#   (',', '.'),
#   ('Marie-Louise', 'NOUN'),
#   ('Giraud', 'NOUN'),
#   (',', '.'),
#   ('carries', 'VERB'),
#   ('historical', 'ADJ'),
#   ('significance', 'NOUN'),
#   (',', '.'),
#   ('both', 'DET'),
#   ('as', 'ADP'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('last', 'ADJ'),
#   ('women', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('executed', 'VERB'),
#   ('*-2', 'X'),
#   ('in', 'ADP'),
#   ('France', 'NOUN'),
#   ('and', 'CONJ'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('symbol', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('Vichy', 'NOUN'),
#   ('government', 'NOUN'),
#   ("'s", 'PRT'),
#   ('hypocrisy', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('``', '.'),
#   ('it', 'PRON'),
#   ('wo', 'VERB'),
#   ("n't", 'ADV'),
#   ('lead', 'VERB'),
#   ('to', 'PRT'),
#   ('imminent', 'ADJ'),
#   ('use', 'NOUN'),
#   ("''", '.'),
#   ('of', 'ADP'),
#   ('new', 'ADJ'),
#   ('superconductors', 'NOUN'),
#   (',', '.'),
#   ('cautioned', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('Robert', 'NOUN'),
#   ('B.', 'NOUN'),
#   ('van', 'NOUN'),
#   ('Dover', 'NOUN'),
#   (',', '.'),
#   ('one', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('AT&T', 'NOUN'),
#   ('researchers', 'NOUN'),
#   ('.', '.')],
#  [('Ginnie', 'NOUN'),
#   ('Mae', 'NOUN'),
#   ("'s", 'PRT'),
#   ('9', 'NUM'),
#   ('%', 'NOUN'),
#   ('issue', 'NOUN'),
#   ('for', 'ADP'),
#   ('November', 'NOUN'),
#   ('delivery', 'NOUN'),
#   ('finished', 'VERB'),
#   ('at', 'ADP'),
#   ('98', 'NUM'),
#   ('5\\/8', 'NUM'),
#   (',', '.'),
#   ('up', 'ADV'),
#   ('2\\/32', 'NUM'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('its', 'PRON'),
#   ('9', 'NUM'),
#   ('1\\/2', 'NUM'),
#   ('%', 'NOUN'),
#   ('issue', 'NOUN'),
#   ('at', 'ADP'),
#   ('100', 'NUM'),
#   ('22\\/32', 'NUM'),
#   (',', '.'),
#   ('also', 'ADV'),
#   ('up', 'ADV'),
#   ('2\\/32', 'NUM'),
#   ('.', '.')],
#  [('A', 'DET'),
#   ('few', 'ADJ'),
#   ('years', 'NOUN'),
#   ('ago', 'ADP'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ('offered', 'VERB'),
#   ('two', 'NUM'),
#   ('round-trip', 'ADJ'),
#   ('tickets', 'NOUN'),
#   ('on', 'ADP'),
#   ('Trans', 'NOUN'),
#   ('World', 'NOUN'),
#   ('Airlines', 'NOUN'),
#   ('to', 'PRT'),
#   ('buyers', 'NOUN'),
#   ('of', 'ADP'),
#   ('its', 'PRON'),
#   ('Riviera', 'NOUN'),
#   ('luxury', 'NOUN'),
#   ('car', 'NOUN'),
#   ('.', '.')],
#  [('Guarantee', 'NOUN'),
#   ('by', 'ADP'),
#   ('Dai-Ichi', 'NOUN'),
#   ('Kangyo', 'NOUN'),
#   ('Bank', 'NOUN'),
#   ('Ltd', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Toronto-based', 'ADJ'),
#   ('real', 'ADJ'),
#   ('estate', 'NOUN'),
#   ('concern', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('each', 'DET'),
#   ('bond', 'NOUN'),
#   ('warrant', 'NOUN'),
#   ('entitles', 'VERB'),
#   ('the', 'DET'),
#   ('holder', 'NOUN'),
#   ('to', 'PRT'),
#   ('buy', 'VERB'),
#   ('C$', '.'),
#   ('1,000', 'NUM'),
#   ('*U*', 'X'),
#   ('principal', 'NOUN'),
#   ('amount', 'NOUN'),
#   ('of', 'ADP'),
#   ('debentures', 'NOUN'),
#   ('at', 'ADP'),
#   ('par', 'NOUN'),
#   ('plus', 'CONJ'),
#   ('accrued', 'VERB'),
#   ('interest', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('date', 'NOUN'),
#   ('of', 'ADP'),
#   ('purchase', 'NOUN'),
#   ('.', '.')],
#  [('Several', 'ADJ'),
#   ('traders', 'NOUN'),
#   ('maintained', 'VERB'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('Merc', 'NOUN'),
#   ("'s", 'PRT'),
#   ('12-point', 'ADJ'),
#   ('circuit-breaker', 'NOUN'),
#   ('aggravated', 'VERB'),
#   ('the', 'DET'),
#   ('market', 'NOUN'),
#   ('slide', 'NOUN'),
#   ('Oct.', 'NOUN'),
#   ('13', 'NUM'),
#   ('by', 'ADP'),
#   ('*-1', 'X'),
#   ('directing', 'VERB'),
#   ('additional', 'ADJ'),
#   ('selling', 'VERB'),
#   ('pressure', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('floor', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('Stock', 'NOUN'),
#   ('Exchange', 'NOUN'),
#   ('.', '.')],
#  [('Program', 'NOUN'),
#   ('trading', 'NOUN'),
#   ('money', 'NOUN'),
#   ('managers', 'NOUN'),
#   ('have', 'VERB'),
#   ('gained', 'VERB'),
#   ('control', 'NOUN'),
#   ('over', 'ADP'),
#   ('a', 'DET'),
#   ('big', 'ADJ'),
#   ('chunk', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('invested', 'VERB'),
#   ('funds', 'NOUN'),
#   ('in', 'ADP'),
#   ('this', 'DET'),
#   ('country', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('pressures', 'NOUN'),
#   ('*ICH*-2', 'X'),
#   ('on', 'ADP'),
#   ('such', 'ADJ'),
#   ('money', 'NOUN'),
#   ('managers', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('produce', 'VERB'),
#   ('consistent', 'ADJ'),
#   ('profits', 'NOUN'),
#   ('has', 'VERB'),
#   ('wedded', 'VERB'),
#   ('them', 'PRON'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('ability', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('move', 'VERB'),
#   ('rapidly', 'ADV'),
#   ('in', 'ADP'),
#   ('and', 'CONJ'),
#   ('out', 'ADP'),
#   ('the', 'DET'),
#   ('market', 'NOUN'),
#   ('that', 'ADP'),
#   ('program', 'NOUN'),
#   ('trading', 'NOUN'),
#   ('gives', 'VERB'),
#   ('them', 'PRON'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('We', 'PRON'),
#   ('have', 'VERB'),
#   ('no', 'DET'),
#   ('doubt', 'NOUN'),
#   ('0', 'X'),
#   ('this', 'DET'),
#   ('is', 'VERB'),
#   ('one', 'NUM'),
#   ('reason', 'NOUN'),
#   ('0', 'X'),
#   ('judges', 'NOUN'),
#   ('in', 'ADP'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('and', 'CONJ'),
#   ('justices', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('Supreme', 'NOUN'),
#   ('Court', 'NOUN'),
#   ('are', 'VERB'),
#   ('willing', 'ADJ'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('trash', 'VERB'),
#   ('the', 'DET'),
#   ('law', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('DES', 'NOUN'),
#   ('cases', 'NOUN'),
#   ('.', '.')],
#  [('On', 'ADP'),
#   ('the', 'DET'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('Mercantile', 'NOUN'),
#   ('Exchange', 'NOUN'),
#   (',', '.'),
#   ('heating', 'NOUN'),
#   ('oil', 'NOUN'),
#   ('for', 'ADP'),
#   ('December', 'NOUN'),
#   ('delivery', 'NOUN'),
#   ('increased', 'VERB'),
#   ('1.25', 'NUM'),
#   ('cents', 'NOUN'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('settle', 'VERB'),
#   ('at', 'ADP'),
#   ('60.36', 'NUM'),
#   ('cents', 'NOUN'),
#   ('a', 'DET'),
#   ('gallon', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('company', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('plans', 'VERB'),
#   ('a', 'DET'),
#   ('fourth-quarter', 'NOUN'),
#   ('charge', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('it', 'PRON'),
#   ('did', 'VERB'),
#   ("n't", 'ADV'),
#   ('specify', 'VERB'),
#   ('*T*-1', 'X'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('an', 'DET'),
#   ('early-retirement', 'ADJ'),
#   ('program', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Japanese', 'ADJ'),
#   ('companies', 'NOUN'),
#   ('bankroll', 'VERB'),
#   ('many', 'ADJ'),
#   ('small', 'ADJ'),
#   ('U.S.', 'NOUN'),
#   ('companies', 'NOUN'),
#   ('with', 'ADP'),
#   ('promising', 'ADJ'),
#   ('products', 'NOUN'),
#   ('or', 'CONJ'),
#   ('ideas', 'NOUN'),
#   (',', '.'),
#   ('*-1', 'X'),
#   ('frequently', 'ADV'),
#   ('putting', 'VERB'),
#   ('their', 'PRON'),
#   ('money', 'NOUN'),
#   ('behind', 'ADP'),
#   ('projects', 'NOUN'),
#   ('that', 'ADP'),
#   ('commercial', 'ADJ'),
#   ('banks', 'NOUN'),
#   ('wo', 'VERB'),
#   ("n't", 'ADV'),
#   ('touch', 'VERB'),
#   ('*T*-191', 'X'),
#   ('.', '.')],
#  [('Performing', 'VERB'), ('loans', 'NOUN'), ('.', '.')],
#  [('All', 'DET'),
#   ('came', 'VERB'),
#   ('from', 'ADP'),
#   ('Cray', 'NOUN'),
#   ('Research', 'NOUN'),
#   ('.', '.')],
#  [('RMS', 'NOUN'),
#   ('distributes', 'VERB'),
#   ('electronic', 'ADJ'),
#   ('devices', 'NOUN'),
#   ('and', 'CONJ'),
#   ('produces', 'VERB'),
#   ('power', 'NOUN'),
#   ('supplies', 'NOUN'),
#   ('and', 'CONJ'),
#   ('plastic', 'ADJ'),
#   ('literature', 'NOUN'),
#   ('displays', 'NOUN'),
#   ('.', '.')],
#  [('Integra', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-174', 'X'),
#   ('owns', 'VERB'),
#   ('and', 'CONJ'),
#   ('operates', 'VERB'),
#   ('hotels', 'NOUN'),
#   (',', '.'),
#   ('said', 'VERB'),
#   ('that', 'ADP'),
#   ('Hallwood', 'NOUN'),
#   ('Group', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   ('has', 'VERB'),
#   ('agreed', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('exercise', 'VERB'),
#   ('any', 'DET'),
#   ('rights', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-175', 'X'),
#   ('are', 'VERB'),
#   ("n't", 'ADV'),
#   ('exercised', 'VERB'),
#   ('*-2', 'X'),
#   ('by', 'ADP'),
#   ('other', 'ADJ'),
#   ('shareholders', 'NOUN'),
#   ('.', '.')],
#  [('Dr.', 'NOUN'),
#   ('Novello', 'NOUN'),
#   ('is', 'VERB'),
#   ('deputy', 'NOUN'),
#   ('director', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('National', 'NOUN'),
#   ('Institute', 'NOUN'),
#   ('of', 'ADP'),
#   ('Child', 'NOUN'),
#   ('Health', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Human', 'NOUN'),
#   ('Development', 'NOUN'),
#   ('.', '.')],
#  [('James', 'NOUN'),
#   ('A.', 'NOUN'),
#   ('White', 'NOUN'),
#   ('contributed', 'VERB'),
#   ('to', 'PRT'),
#   ('this', 'DET'),
#   ('article', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('competitive', 'ADJ'),
#   ('rates', 'NOUN'),
#   ('were', 'VERB'),
#   ('generally', 'ADV'),
#   ('offset', 'VERB'),
#   ('*-1', 'X'),
#   ('by', 'ADP'),
#   ('hefty', 'ADJ'),
#   ('fees', 'NOUN'),
#   ('on', 'ADP'),
#   ('various', 'ADJ'),
#   ('services', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('and', 'CONJ'),
#   ('his', 'PRON'),
#   ('successor', 'NOUN'),
#   (',', '.'),
#   ('Mary', 'NOUN'),
#   ('Anne', 'NOUN'),
#   ('Dolan', 'NOUN'),
#   (',', '.'),
#   ('restored', 'VERB'),
#   ('respect', 'NOUN'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('editorial', 'NOUN'),
#   ('product', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('though', 'ADP'),
#   ('in', 'ADP'),
#   ('recent', 'ADJ'),
#   ('years', 'NOUN'),
#   ('the', 'DET'),
#   ('paper', 'NOUN'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('limping', 'VERB'),
#   ('along', 'ADP'),
#   ('on', 'ADP'),
#   ('limited', 'VERB'),
#   ('resources', 'NOUN'),
#   (',', '.'),
#   ('its', 'PRON'),
#   ('accomplishments', 'NOUN'),
#   ('were', 'VERB'),
#   ('notable', 'ADJ'),
#   ('.', '.')],
#  [('9.82', 'NUM'),
#   ('%', 'NOUN'),
#   (',', '.'),
#   ('standard', 'ADJ'),
#   ('conventional', 'ADJ'),
#   ('fixed-rate', 'ADJ'),
#   ('mortgages', 'NOUN'),
#   (';', '.'),
#   ('8.25', 'NUM'),
#   ('%', 'NOUN'),
#   (',', '.'),
#   ('2', 'NUM'),
#   ('%', 'NOUN'),
#   ('rate', 'NOUN'),
#   ('capped', 'ADJ'),
#   ('one-year', 'ADJ'),
#   ('adjustable', 'ADJ'),
#   ('rate', 'NOUN'),
#   ('mortgages', 'NOUN'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('particular', 'ADJ'),
#   (',', '.'),
#   ('Mr.', 'NOUN'),
#   ('Coxon', 'NOUN'),
#   ('says', 'VERB'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   (',', '.'),
#   ('businesses', 'NOUN'),
#   ('are', 'VERB'),
#   ('paying', 'VERB'),
#   ('out', 'PRT'),
#   ('a', 'DET'),
#   ('smaller', 'ADJ'),
#   ('percentage', 'NOUN'),
#   ('of', 'ADP'),
#   ('their', 'PRON'),
#   ('profits', 'NOUN'),
#   ('and', 'CONJ'),
#   ('cash', 'NOUN'),
#   ('flow', 'NOUN'),
#   ('*ICH*-3', 'X'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('form', 'NOUN'),
#   ('of', 'ADP'),
#   ('dividends', 'NOUN'),
#   ('than', 'ADP'),
#   ('they', 'PRON'),
#   ('have', 'VERB'),
#   ('*?*', 'X'),
#   ('historically', 'ADV'),
#   ('.', '.')],
#  [('Michelin', 'NOUN'),
#   ('officials', 'NOUN'),
#   ('could', 'VERB'),
#   ("n't", 'ADV'),
#   ('immediately', 'ADV'),
#   ('comment', 'VERB'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('referral', 'NOUN'),
#   (',', '.'),
#   ('but', 'CONJ'),
#   ('they', 'PRON'),
#   ('noted', 'VERB'),
#   ('0', 'X'),
#   ('the', 'DET'),
#   ('purchase', 'NOUN'),
#   ('from', 'ADP'),
#   ('BTR', 'NOUN'),
#   ('has', 'VERB'),
#   ('already', 'ADV'),
#   ('been', 'VERB'),
#   ('concluded', 'VERB'),
#   ('*-1', 'X'),
#   ('.', '.')],
#  [('Indeed', 'ADV'),
#   (',', '.'),
#   ('Mrs.', 'NOUN'),
#   ('Yeargin', 'NOUN'),
#   ('was', 'VERB'),
#   ('interested', 'ADJ'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('possible', 'ADJ'),
#   ('job', 'NOUN'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('state', 'NOUN'),
#   ('teacher', 'NOUN'),
#   ('cadet', 'NOUN'),
#   ('program', 'NOUN'),
#   ('.', '.')],
#  [('Financially', 'ADV'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('never', 'ADV'),
#   ('recovered', 'VERB'),
#   (';', '.'),
#   ('editorially', 'ADV'),
#   (',', '.'),
#   ('it', 'PRON'),
#   ('had', 'VERB'),
#   ('its', 'PRON'),
#   ('moments', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('some', 'DET'),
#   ('investors', 'NOUN'),
#   ('have', 'VERB'),
#   ('used', 'VERB'),
#   ('such', 'ADJ'),
#   ('filings', 'NOUN'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('boost', 'VERB'),
#   ('the', 'DET'),
#   ('value', 'NOUN'),
#   ('of', 'ADP'),
#   ('their', 'PRON'),
#   ('stock', 'NOUN'),
#   ('holdings', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('--', '.'),
#   ('without', 'ADP'),
#   ('*-2', 'X'),
#   ('buying', 'VERB'),
#   ('more', 'ADJ'),
#   ('stock', 'NOUN'),
#   ('--', '.'),
#   ('they', 'PRON'),
#   ('then', 'ADV'),
#   ('sold', 'VERB'),
#   ('*T*-3', 'X'),
#   ('.', '.')],
#  [('*-1', 'X'),
#   ('Asked', 'VERB'),
#   ('*-2', 'X'),
#   ('whether', 'ADP'),
#   ('potential', 'ADJ'),
#   ('advertisers', 'NOUN'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('scared', 'VERB'),
#   ('*-83', 'X'),
#   ('away', 'ADV'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('magazine', 'NOUN'),
#   ("'s", 'PRT'),
#   ('direct', 'ADJ'),
#   ('policy', 'NOUN'),
#   (',', '.'),
#   ('Ms.', 'NOUN'),
#   ('Poore', 'NOUN'),
#   ('replies', 'VERB'),
#   (':', '.'),
#   ('``', '.'),
#   ('I', 'PRON'),
#   ('do', 'VERB'),
#   ("n't", 'ADV'),
#   ('know', 'VERB'),
#   ('and', 'CONJ'),
#   ('I', 'PRON'),
#   ('do', 'VERB'),
#   ("n't", 'ADV'),
#   ('care', 'VERB'),
#   ('.', '.')],
#  [('``', '.'),
#   ('U.S.', 'NOUN'),
#   ('investors', 'NOUN'),
#   ('should', 'VERB'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('greater', 'ADJ'),
#   ('opportunity', 'NOUN'),
#   ('at', 'ADP'),
#   ('direct', 'ADJ'),
#   ('investment', 'NOUN'),
#   ("''", '.'),
#   ('in', 'ADP'),
#   ('Japan', 'NOUN'),
#   ('.', '.')],
#  [('*-1', 'X'),
#   ('Stung', 'VERB'),
#   ('by', 'ADP'),
#   ('charges', 'NOUN'),
#   ('that', 'ADP'),
#   ('their', 'PRON'),
#   ('greed', 'NOUN'),
#   ('is', 'VERB'),
#   ('turning', 'VERB'),
#   ('the', 'DET'),
#   ('stock', 'NOUN'),
#   ('market', 'NOUN'),
#   ('into', 'ADP'),
#   ('a', 'DET'),
#   ('gigantic', 'ADJ'),
#   ('crapshoot', 'NOUN'),
#   (',', '.'),
#   ('almost', 'ADV'),
#   ('all', 'DET'),
#   ('the', 'DET'),
#   ('big', 'ADJ'),
#   ('investment', 'NOUN'),
#   ('banking', 'NOUN'),
#   ('houses', 'NOUN'),
#   ('have', 'VERB'),
#   ('abandoned', 'VERB'),
#   ('index', 'NOUN'),
#   ('arbitrage', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('common', 'ADJ'),
#   ('form', 'NOUN'),
#   ('of', 'ADP'),
#   ('program', 'NOUN'),
#   ('trading', 'NOUN'),
#   (',', '.'),
#   ('for', 'ADP'),
#   ('their', 'PRON'),
#   ('own', 'ADJ'),
#   ('accounts', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('past', 'ADJ'),
#   ('few', 'ADJ'),
#   ('days', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('added', 'VERB'),
#   (',', '.'),
#   ('``', '.'),
#   ('There', 'DET'),
#   ("'s", 'VERB'),
#   ('nothing', 'NOUN'),
#   ('very', 'ADV'),
#   ('hot', 'ADJ'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Dreyfus', 'NOUN'),
#   ('World-Wide', 'NOUN'),
#   ('Dollar', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('top-yielding', 'ADJ'),
#   ('fund', 'NOUN'),
#   (',', '.'),
#   ('had', 'VERB'),
#   ('a', 'DET'),
#   ('seven-day', 'ADJ'),
#   ('compound', 'NOUN'),
#   ('yield', 'NOUN'),
#   ('of', 'ADP'),
#   ('9.37', 'NUM'),
#   ('%', 'NOUN'),
#   ('during', 'ADP'),
#   ('the', 'DET'),
#   ('latest', 'ADJ'),
#   ('week', 'NOUN'),
#   (',', '.'),
#   ('down', 'ADV'),
#   ('from', 'ADP'),
#   ('9.45', 'NUM'),
#   ('%', 'NOUN'),
#   ('a', 'DET'),
#   ('week', 'NOUN'),
#   ('earlier', 'ADJ'),
#   ('.', '.')],
#  [('Pictures', 'NOUN'),
#   ('of', 'ADP'),
#   ('rusted', 'VERB'),
#   ('oil', 'NOUN'),
#   ('drums', 'NOUN'),
#   ('swim', 'VERB'),
#   ('into', 'ADP'),
#   ('focus', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('female', 'ADJ'),
#   ('voice', 'NOUN'),
#   ('purrs', 'VERB'),
#   (',', '.'),
#   ('``', '.'),
#   ('That', 'DET'),
#   ('hazardous', 'ADJ'),
#   ('waste', 'NOUN'),
#   ('on', 'ADP'),
#   ('his', 'PRON'),
#   ('-LCB-', '.'),
#   ('Mr.', 'NOUN'),
#   ('Courter', 'NOUN'),
#   ("'s", 'PRT'),
#   ('-RCB-', '.'),
#   ('property', 'NOUN'),
#   ('--', '.'),
#   ('the', 'DET'),
#   ('neighbors', 'NOUN'),
#   ('are', 'VERB'),
#   ('suing', 'VERB'),
#   ('for', 'ADP'),
#   ('consumer', 'NOUN'),
#   ('fraud', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Mrs.', 'NOUN'),
#   ('Yeargin', 'NOUN'),
#   ('admits', 'VERB'),
#   ('0', 'X'),
#   ('she', 'PRON'),
#   ('made', 'VERB'),
#   ('a', 'DET'),
#   ('big', 'ADJ'),
#   ('mistake', 'NOUN'),
#   ('but', 'CONJ'),
#   ('insists', 'VERB'),
#   ('0', 'X'),
#   ('her', 'PRON'),
#   ('motives', 'NOUN'),
#   ('were', 'VERB'),
#   ('correct', 'ADJ'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('multilevel', 'ADJ'),
#   ('railcars', 'NOUN'),
#   (',', '.'),
#   ('scheduled', 'VERB'),
#   ('*', 'X'),
#   ('for', 'ADP'),
#   ('delivery', 'NOUN'),
#   ('in', 'ADP'),
#   ('1990', 'NUM'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('made', 'VERB'),
#   ('*-1', 'X'),
#   ('by', 'ADP'),
#   ('Thrall', 'NOUN'),
#   ('Manufacturing', 'NOUN'),
#   ('Co.', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('Chicago', 'NOUN'),
#   ('Heights', 'NOUN'),
#   (',', '.'),
#   ('Ill.', 'NOUN'),
#   (',', '.'),
#   ('division', 'NOUN'),
#   ('of', 'ADP'),
#   ('closely', 'ADV'),
#   ('held', 'VERB'),
#   ('Duchossois', 'NOUN'),
#   ('Industries', 'NOUN'),
#   ('Inc.', 'NOUN'),
#   (',', '.'),
#   ('Elmhurst', 'NOUN'),
#   (',', '.'),
#   ('Ill', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('documents', 'NOUN'),
#   ('also', 'ADV'),
#   ('said', 'VERB'),
#   ('that', 'ADP'),
#   ('Cray', 'NOUN'),
#   ('Computer', 'NOUN'),
#   ('anticipates', 'VERB'),
#   ('*-1', 'X'),
#   ('needing', 'VERB'),
#   ('perhaps', 'ADV'),
#   ('another', 'DET'),
#   ('$', '.'),
#   ('120', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('in', 'ADP'),
#   ('financing', 'NOUN'),
#   ('beginning', 'VERB'),
#   ('next', 'ADJ'),
#   ('September', 'NOUN'),
#   ('.', '.')],
#  [('By', 'ADP'),
#   ('1997', 'NUM'),
#   (',', '.'),
#   ('almost', 'ADV'),
#   ('all', 'DET'),
#   ('remaining', 'VERB'),
#   ('uses', 'NOUN'),
#   ('of', 'ADP'),
#   ('cancer-causing', 'ADJ'),
#   ('asbestos', 'NOUN'),
#   ('will', 'VERB'),
#   ('be', 'VERB'),
#   ('outlawed', 'VERB'),
#   ('*-6', 'X'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('addition', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('damages', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('suit', 'NOUN'),
#   ('seeks', 'VERB'),
#   ('a', 'DET'),
#   ('court', 'NOUN'),
#   ('order', 'NOUN'),
#   ('preventing', 'VERB'),
#   ('the', 'DET'),
#   ('guild', 'NOUN'),
#   ('from', 'ADP'),
#   ('*-2', 'X'),
#   ('punishing', 'VERB'),
#   ('*RNR*-1', 'X'),
#   ('or', 'CONJ'),
#   ('retaliating', 'VERB'),
#   ('against', 'ADP'),
#   ('*RNR*-1', 'X'),
#   ('Mr.', 'NOUN'),
#   ('Trudeau', 'NOUN'),
#   ('.', '.')],
#  [('If', 'ADP'),
#   (',', '.'),
#   ('when', 'ADV'),
#   ('trading', 'NOUN'),
#   ('resumes', 'VERB'),
#   ('*T*-1', 'X'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('S&P', 'NOUN'),
#   ('futures', 'NOUN'),
#   ('fall', 'VERB'),
#   ('30', 'NUM'),
#   ('points', 'NOUN'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('previous', 'ADJ'),
#   ('day', 'NOUN'),
#   ("'s", 'PRT'),
#   ('close', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('one-hour', 'ADJ'),
#   ('trading', 'NOUN'),
#   ('halt', 'NOUN'),
#   ('takes', 'VERB'),
#   ('effect', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('screen', 'NOUN'),
#   ('fills', 'VERB'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('small', 'ADJ'),
#   (',', '.'),
#   ('tight', 'ADJ'),
#   ('facial', 'ADJ'),
#   ('shot', 'NOUN'),
#   ('of', 'ADP'),
#   ('David', 'NOUN'),
#   ('Dinkins', 'NOUN'),
#   (',', '.'),
#   ('Democratic', 'ADJ'),
#   ('candidate', 'NOUN'),
#   ('for', 'ADP'),
#   ('mayor', 'NOUN'),
#   ('of', 'ADP'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('City', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('last', 'ADJ'),
#   ('thing', 'NOUN'),
#   ('0', 'X'),
#   ('they', 'PRON'),
#   ('needed', 'VERB'),
#   ('*T*-1', 'X'),
#   ('was', 'VERB'),
#   ('another', 'DET'),
#   ('drag-down', 'ADJ'),
#   ('blow', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Lewis', 'NOUN'),
#   ('C.', 'NOUN'),
#   ('Veraldi', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('father', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('team', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('created', 'VERB'),
#   ('the', 'DET'),
#   ('highly', 'ADV'),
#   ('successful', 'ADJ'),
#   ('Ford', 'NOUN'),
#   ('Taurus', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Mercury', 'NOUN'),
#   ('Sable', 'NOUN'),
#   ('cars', 'NOUN'),
#   (',', '.'),
#   ('retired', 'VERB'),
#   ('early', 'ADV'),
#   ('after', 'ADP'),
#   ('*-2', 'X'),
#   ('experiencing', 'VERB'),
#   ('recent', 'ADJ'),
#   ('heart', 'NOUN'),
#   ('problems', 'NOUN'),
#   ('.', '.')],
#  [('He', 'PRON'),
#   ('added', 'VERB'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('current-carrying', 'ADJ'),
#   ('capacity', 'NOUN'),
#   ('of', 'ADP'),
#   ('multi-crystal', 'ADJ'),
#   ('samples', 'NOUN'),
#   ('of', 'ADP'),
#   ('superconductors', 'NOUN'),
#   ('remains', 'VERB'),
#   ('too', 'ADV'),
#   ('low', 'ADV'),
#   ('for', 'ADP'),
#   ('most', 'ADJ'),
#   ('practical', 'ADJ'),
#   ('uses', 'NOUN'),
#   ('because', 'ADP'),
#   ('of', 'ADP'),
#   ('so-called', 'ADJ'),
#   ('weak', 'ADJ'),
#   ('links', 'NOUN'),
#   ('between', 'ADP'),
#   ('crystals', 'NOUN'),
#   ('.', '.')],
#  [('Younkers', 'NOUN'),
#   ('rang', 'VERB'),
#   ('up', 'PRT'),
#   ('sales', 'NOUN'),
#   ('*ICH*-1', 'X'),
#   ('in', 'ADP'),
#   ('1988', 'NUM'),
#   ('of', 'ADP'),
#   ('$', '.'),
#   ('313', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('*', 'X'),
#   ('Getting', 'VERB'),
#   ('a', 'DET'),
#   ('level', 'NOUN'),
#   ('playing', 'NOUN'),
#   ('field', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Hahn', 'NOUN'),
#   ('attributes', 'VERB'),
#   ('the', 'DET'),
#   ('gains', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('philosophy', 'NOUN'),
#   ('of', 'ADP'),
#   ('*', 'X'),
#   ('concentrating', 'VERB'),
#   ('on', 'ADP'),
#   ('what', 'PRON'),
#   ('a', 'DET'),
#   ('company', 'NOUN'),
#   ('knows', 'VERB'),
#   ('*T*-1', 'X'),
#   ('best', 'ADJ'),
#   ('.', '.')],
#  [('``', '.'),
#   ('The', 'DET'),
#   ('USIA', 'NOUN'),
#   ('officially', 'ADV'),
#   ('and', 'CONJ'),
#   ('publicly', 'ADV'),
#   ('declared', 'VERB'),
#   ('the', 'DET'),
#   ('absolute', 'ADJ'),
#   ('right', 'NOUN'),
#   ('*ICH*-2', 'X'),
#   ('of', 'ADP'),
#   ('everyone', 'NOUN'),
#   ('except', 'ADP'),
#   ('the', 'DET'),
#   ('USIA', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('disseminate', 'VERB'),
#   ('agency', 'NOUN'),
#   ('program', 'NOUN'),
#   ('materials', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('United', 'NOUN'),
#   ('States', 'NOUN'),
#   (',', '.'),
#   ("''", '.'),
#   ('my', 'PRON'),
#   ('lawyer', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('scholarly', 'ADJ'),
#   ('Mark', 'NOUN'),
#   ('McCormick', 'NOUN'),
#   ('of', 'ADP'),
#   ('Des', 'NOUN'),
#   ('Moines', 'NOUN'),
#   (',', '.'),
#   ('said', 'VERB'),
#   ('*T*-1', 'X'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('memo', 'NOUN'),
#   ('pointing', 'VERB'),
#   ('out', 'PRT'),
#   ('the', 'DET'),
#   ('facts', 'NOUN'),
#   ('and', 'CONJ'),
#   ('trying', 'VERB'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('make', 'VERB'),
#   ('me', 'PRON'),
#   ('feel', 'VERB'),
#   ('good', 'ADJ'),
#   ('after', 'ADP'),
#   ('the', 'DET'),
#   ('press', 'NOUN'),
#   ('reported', 'VERB'),
#   ('that', 'ADP'),
#   ('I', 'PRON'),
#   ('had', 'VERB'),
#   ('lost', 'VERB'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('theory', 'NOUN'),
#   (':', '.'),
#   ('Such', 'ADJ'),
#   ('individuals', 'NOUN'),
#   (',', '.'),
#   ('many', 'ADJ'),
#   ('with', 'ADP'),
#   ('young', 'ADJ'),
#   ('children', 'NOUN'),
#   (',', '.'),
#   ('are', 'VERB'),
#   ('in', 'ADP'),
#   ('their', 'PRON'),
#   ('prime', 'ADJ'),
#   ('borrowing', 'VERB'),
#   ('years', 'NOUN'),
#   ('--', '.'),
#   ('and', 'ADJ'),
#   (',', '.'),
#   ('*-1', 'X'),
#   ('having', 'VERB'),
#   ('borrowed', 'VERB'),
#   ('from', 'ADP'),
#   ('the', 'DET'),
#   ('bank', 'NOUN'),
#   (',', '.'),
#   ('they', 'PRON'),
#   ('may', 'VERB'),
#   ('continue', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('use', 'VERB'),
#   ('it', 'PRON'),
#   ('for', 'ADP'),
#   ('other', 'ADJ'),
#   ('services', 'NOUN'),
#   ('in', 'ADP'),
#   ('later', 'ADJ'),
#   ('years', 'NOUN'),
#   ('.', '.')],
#  [('California', 'NOUN'),
#   ('led', 'VERB'),
#   ('the', 'DET'),
#   ('nation', 'NOUN'),
#   ('with', 'ADP'),
#   ('$', '.'),
#   ('6.5', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   ('in', 'ADP'),
#   ('net', 'ADJ'),
#   ('cash', 'NOUN'),
#   ('income', 'NOUN'),
#   ('last', 'ADJ'),
#   ('year', 'NOUN'),
#   (',', '.'),
#   ('followed', 'VERB'),
#   ('by', 'ADP'),
#   ('Texas', 'NOUN'),
#   (',', '.'),
#   ('$', '.'),
#   ('3.9', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   (';', '.'),
#   ('Iowa', 'NOUN'),
#   (',', '.'),
#   ('$', '.'),
#   ('3.4', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   (';', '.'),
#   ('Florida', 'NOUN'),
#   (',', '.'),
#   ('$', '.'),
#   ('3.1', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('Minnesota', 'NOUN'),
#   (',', '.'),
#   ('$', '.'),
#   ('2.7', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Thomas', 'NOUN'),
#   (',', '.'),
#   ('currently', 'ADV'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('Equal', 'NOUN'),
#   ('Employment', 'NOUN'),
#   ('Opportunity', 'NOUN'),
#   ('Commission', 'NOUN'),
#   (',', '.'),
#   ('would', 'VERB'),
#   ('add', 'VERB'),
#   ('another', 'DET'),
#   ('conservative', 'ADJ'),
#   ('voice', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('closely', 'ADV'),
#   ('divided', 'VERB'),
#   ('court', 'NOUN'),
#   ('.', '.')],
#  [('Ms.', 'NOUN'),
#   ('Kirkpatrick', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Journal', 'NOUN'),
#   ("'s", 'PRT'),
#   ('deputy', 'NOUN'),
#   ('editorial', 'NOUN'),
#   ('features', 'NOUN'),
#   ('editor', 'NOUN'),
#   (',', '.'),
#   ('worked', 'VERB'),
#   ('in', 'ADP'),
#   ('Tokyo', 'NOUN'),
#   ('for', 'ADP'),
#   ('three', 'NUM'),
#   ('years', 'NOUN'),
#   ('.', '.')],
#  [('``', '.'),
#   ('You', 'PRON'),
#   ('have', 'VERB'),
#   ('...', '.'),
#   ('raised', 'VERB'),
#   ('important', 'ADJ'),
#   ('questions', 'NOUN'),
#   ('which', 'DET'),
#   ('*T*-26', 'X'),
#   ('ought', 'VERB'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('be', 'VERB'),
#   ('answered', 'VERB'),
#   ('*-3', 'X'),
#   (':', '.'),
#   ('What', 'PRON'),
#   ('does', 'VERB'),
#   ('USIA', 'NOUN'),
#   ('say', 'VERB'),
#   ('*T*-27', 'X'),
#   ('about', 'ADP'),
#   ('America', 'NOUN'),
#   ('abroad', 'ADV'),
#   (';', '.'),
#   ('how', 'ADV'),
#   ('do', 'VERB'),
#   ('we', 'PRON'),
#   ('say', 'VERB'),
#   ('it', 'PRON'),
#   ('*T*-4', 'X'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('how', 'ADV'),
#   ('can', 'VERB'),
#   ('American', 'ADJ'),
# ...
#   ('be', 'VERB'),
#   ('some', 'DET'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('same', 'ADJ'),
#   ('folks', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-153', 'X'),
#   ('are', 'VERB'),
#   ('major', 'ADJ'),
#   ('magazine', 'NOUN'),
#   ('advertisers', 'NOUN'),
#   ('these', 'DET'),
#   ('days', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('company', 'NOUN'),
#   ('earlier', 'ADV'),
#   ('this', 'DET'),
#   ('year', 'NOUN'),
#   ('adopted', 'VERB'),
#   ('a', 'DET'),
#   ('shareholder-rights', 'ADJ'),
#   ('plan', 'NOUN'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('ward', 'VERB'),
#   ('off', 'PRT'),
#   ('unwanted', 'ADJ'),
#   ('suitors', 'NOUN'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('anticipation', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('start-up', 'NOUN'),
#   ('of', 'ADP'),
#   ('its', 'PRON'),
#   ('new', 'ADJ'),
#   ('factory', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('a', 'DET'),
#   ('larger-than-normal', 'ADJ'),
#   ('chassis', 'NOUN'),
#   ('supply', 'NOUN'),
#   ('has', 'VERB'),
#   ('been', 'VERB'),
#   ('built', 'VERB'),
#   ('*-1', 'X'),
#   ('0', 'X'),
#   ('*T*-2', 'X'),
#   ('to', 'PRT'),
#   ('carry', 'VERB'),
#   ('it', 'PRON'),
#   ('through', 'ADP'),
#   ('the', 'DET'),
#   ('transition', 'NOUN'),
#   ('period', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Reupke', 'NOUN'),
#   (',', '.'),
#   ('52', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   ('and', 'CONJ'),
#   ('a', 'DET'),
#   ('27-year', 'ADJ'),
#   ('Reuters', 'NOUN'),
#   ('veteran', 'NOUN'),
#   (',', '.'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('the', 'DET'),
#   ('information-services', 'NOUN'),
#   ('company', 'NOUN'),
#   ("'s", 'PRT'),
#   ('general', 'ADJ'),
#   ('manager', 'NOUN'),
#   ('for', 'ADP'),
#   ('only', 'ADV'),
#   ('six', 'NUM'),
#   ('months', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Bernstein', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('tall', 'ADJ'),
#   (',', '.'),
#   ('energetic', 'ADJ'),
#   ('man', 'NOUN'),
#   ('who', 'PRON'),
#   ('*T*-39', 'X'),
#   ('is', 'VERB'),
#   ('widely', 'ADV'),
#   ('respected', 'VERB'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('publishing', 'NOUN'),
#   ('executive', 'NOUN'),
#   (',', '.'),
#   ('has', 'VERB'),
#   ('spent', 'VERB'),
#   ('much', 'ADJ'),
#   ('of', 'ADP'),
#   ('his', 'PRON'),
#   ('time', 'NOUN'),
#   ('in', 'ADP'),
#   ('recent', 'ADJ'),
#   ('years', 'NOUN'),
#   ('on', 'ADP'),
#   ('human', 'ADJ'),
#   ('rights', 'NOUN'),
#   ('issues', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('Big', 'NOUN'),
#   ('Board', 'NOUN'),
#   ('--', '.'),
#   ('the', 'DET'),
#   ('nation', 'NOUN'),
#   ("'s", 'PRT'),
#   ('premier', 'ADJ'),
#   ('stock', 'NOUN'),
#   ('exchange', 'NOUN'),
#   ('--', '.'),
#   ('is', 'VERB'),
#   ('sharply', 'ADV'),
#   ('divided', 'VERB'),
#   ('between', 'ADP'),
#   ('its', 'PRON'),
#   ('floor', 'NOUN'),
#   ('traders', 'NOUN'),
#   ('and', 'CONJ'),
#   ('its', 'PRON'),
#   ('top', 'ADJ'),
#   ('executives', 'NOUN'),
#   ('.', '.')],
#  [('Those', 'DET'),
#   ('countries', 'NOUN'),
#   ('--', '.'),
#   ('including', 'ADP'),
#   ('Japan', 'NOUN'),
#   (',', '.'),
#   ('Italy', 'NOUN'),
#   (',', '.'),
#   ('Canada', 'NOUN'),
#   (',', '.'),
#   ('Greece', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Spain', 'NOUN'),
#   ('--', '.'),
#   ('are', 'VERB'),
#   ('still', 'ADV'),
#   ('of', 'ADP'),
#   ('some', 'DET'),
#   ('concern', 'NOUN'),
#   ('to', 'PRT'),
#   ('the', 'DET'),
#   ('U.S.', 'NOUN'),
#   ('but', 'CONJ'),
#   ('are', 'VERB'),
#   ('deemed', 'VERB'),
#   ('*-1', 'X'),
#   ('to', 'PRT'),
#   ('pose', 'VERB'),
#   ('less-serious', 'ADJ'),
#   ('problems', 'NOUN'),
#   ('for', 'ADP'),
#   ('American', 'ADJ'),
#   ('patent', 'NOUN'),
#   ('and', 'CONJ'),
#   ('copyright', 'NOUN'),
#   ('owners', 'NOUN'),
#   ('than', 'ADP'),
#   ('those', 'DET'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('``', '.'),
#   ('priority', 'NOUN'),
#   ("''", '.'),
#   ('list', 'NOUN'),
#   ('.', '.')],
#  [('But', 'CONJ'),
#   ('as', 'ADP'),
#   ('Duke', 'NOUN'),
#   ('University', 'NOUN'),
#   ('law', 'NOUN'),
#   ('professor', 'NOUN'),
#   ('William', 'NOUN'),
#   ('Van', 'NOUN'),
#   ('Alstyne', 'NOUN'),
#   ('notes', 'VERB'),
#   (',', '.'),
#   ('by', 'ADP'),
#   ('this', 'DET'),
#   ('reasoning', 'NOUN'),
#   ('a', 'DET'),
#   ('defendant', 'NOUN'),
#   ('could', 'VERB'),
#   ('be', 'VERB'),
#   ('held', 'VERB'),
#   ('*-1', 'X'),
#   ('liable', 'ADJ'),
#   ('in', 'ADP'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('for', 'ADP'),
#   ('a', 'DET'),
#   ('bad', 'ADJ'),
#   ('apple', 'NOUN'),
#   ('even', 'ADV'),
#   ('if', 'ADP'),
#   ('he', 'PRON'),
#   ('sold', 'VERB'),
#   ('all', 'DET'),
#   ('his', 'PRON'),
#   ('apples', 'NOUN'),
#   ('in', 'ADP'),
#   ('California', 'NOUN'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('ban', 'NOUN'),
#   ('on', 'ADP'),
#   ('cross-border', 'ADJ'),
#   ('movement', 'NOUN'),
#   ('was', 'VERB'),
#   ('imposed', 'VERB'),
#   ('*-1', 'X'),
#   ('last', 'ADJ'),
#   ('month', 'NOUN'),
#   ('after', 'ADP'),
#   ('a', 'DET'),
#   ('massive', 'ADJ'),
#   ('exodus', 'NOUN'),
#   ('of', 'ADP'),
#   ('emigres', 'NOUN'),
#   ('to', 'PRT'),
#   ('West', 'NOUN'),
#   ('Germany', 'NOUN'),
#   ('.', '.')],
#  [('*-2', 'X'),
#   ('Knowing', 'VERB'),
#   ('a', 'DET'),
#   ('tasty', 'ADJ'),
#   ('--', '.'),
#   ('and', 'CONJ'),
#   ('free', 'ADJ'),
#   ('--', '.'),
#   ('meal', 'NOUN'),
#   ('when', 'ADV'),
#   ('they', 'PRON'),
#   ('eat', 'VERB'),
#   ('one', 'NUM'),
#   ('*T*-1', 'X'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('executives', 'NOUN'),
#   ('gave', 'VERB'),
#   ('the', 'DET'),
#   ('chefs', 'NOUN'),
#   ('a', 'DET'),
#   ('standing', 'ADJ'),
#   ('ovation', 'NOUN'),
#   ('.', '.')],
#  [('Robert', 'NOUN'),
#   ('J.', 'NOUN'),
#   ('Danzig', 'NOUN'),
#   (',', '.'),
#   ('vice', 'NOUN'),
#   ('president', 'NOUN'),
#   ('*RNR*-1', 'X'),
#   ('and', 'CONJ'),
#   ('general', 'ADJ'),
#   ('manager', 'NOUN'),
#   ('*RNR*-1', 'X'),
#   ('of', 'ADP'),
#   ('Hearst', 'NOUN'),
#   ('Newspapers', 'NOUN'),
#   (',', '.'),
#   ('stood', 'VERB'),
#   ('up', 'PRT'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('paper', 'NOUN'),
#   ("'s", 'PRT'),
#   ('newsroom', 'NOUN'),
#   ('yesterday', 'NOUN'),
#   ('and', 'CONJ'),
#   ('announced', 'VERB'),
#   ('that', 'ADP'),
#   ('no', 'DET'),
#   ('buyers', 'NOUN'),
#   ('had', 'VERB'),
#   ('stepped', 'VERB'),
#   ('forward', 'ADV'),
#   ('and', 'CONJ'),
#   ('that', 'ADP'),
#   ('the', 'DET'),
#   ('paper', 'NOUN'),
#   ('would', 'VERB'),
#   ('fold', 'VERB'),
#   (',', '.'),
#   ('*-2', 'X'),
#   ('putting', 'VERB'),
#   ('more', 'ADJ'),
#   ('than', 'ADP'),
#   ('730', 'NUM'),
#   ('full-time', 'ADJ'),
#   ('employees', 'NOUN'),
#   ('out', 'ADP'),
#   ('of', 'ADP'),
#   ('work', 'NOUN'),
#   ('.', '.')],
#  [('*-1', 'X'),
#   ('Not', 'ADV'),
#   ('counting', 'VERB'),
#   ('the', 'DET'),
#   ('extraordinary', 'ADJ'),
#   ('charge', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('it', 'PRON'),
#   ('would', 'VERB'),
#   ('have', 'VERB'),
#   ('had', 'VERB'),
#   ('a', 'DET'),
#   ('net', 'ADJ'),
#   ('loss', 'NOUN'),
#   ('of', 'ADP'),
#   ('$', '.'),
#   ('3.1', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   (',', '.'),
#   ('or', 'CONJ'),
#   ('seven', 'NUM'),
#   ('cents', 'NOUN'),
#   ('a', 'DET'),
#   ('share', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Russell', 'NOUN'),
#   (',', '.'),
#   ('who', 'PRON'),
#   ('*T*-1', 'X'),
#   ('co-founded', 'VERB'),
#   ('the', 'DET'),
#   ('Kansas', 'NOUN'),
#   ('City', 'NOUN'),
#   (',', '.'),
#   ('Mo.-based', 'ADJ'),
#   ('local', 'ADJ'),
#   ('business', 'NOUN'),
#   ('publications', 'NOUN'),
#   ('concern', 'NOUN'),
#   ('here', 'ADV'),
#   (',', '.'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('he', 'PRON'),
#   ('would', 'VERB'),
#   ('have', 'VERB'),
#   ('a', 'DET'),
#   ('five-year', 'ADJ'),
#   ('consulting', 'NOUN'),
#   ('agreement', 'NOUN'),
#   ('with', 'ADP'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-2', 'X'),
#   ('recently', 'ADV'),
#   ('underwent', 'VERB'),
#   ('an', 'DET'),
#   ('ownership', 'NOUN'),
#   ('change', 'NOUN'),
#   ('.', '.')],
#  [('Today', 'NOUN'),
#   (',', '.'),
#   ('PC', 'NOUN'),
#   ('shipments', 'NOUN'),
#   ('annually', 'ADV'),
#   ('total', 'VERB'),
#   ('some', 'DET'),
#   ('$', '.'),
#   ('38.3', 'NUM'),
#   ('billion', 'NUM'),
#   ('*U*', 'X'),
#   ('world-wide', 'ADJ'),
#   ('.', '.')],
#  [('The', 'DET'),
#   ('latest', 'ADJ'),
#   ('results', 'NOUN'),
#   ('include', 'VERB'),
#   ('some', 'DET'),
#   ('unusual', 'ADJ'),
#   ('write-downs', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-1', 'X'),
#   ('had', 'VERB'),
#   ('an', 'DET'),
#   ('after-tax', 'ADJ'),
#   ('impact', 'NOUN'),
#   ('of', 'ADP'),
#   ('$', '.'),
#   ('4.9', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('.', '.')],
#  [('Temple', 'NOUN'),
#   ('added', 'VERB'),
#   ('that', 'ADP'),
#   ('Sea', 'NOUN'),
#   ('Containers', 'NOUN'),
#   ('is', 'VERB'),
#   ('still', 'ADV'),
#   ('mired', 'VERB'),
#   ('*-2', 'X'),
#   ('in', 'ADP'),
#   ('legal', 'ADJ'),
#   ('problems', 'NOUN'),
#   ('in', 'ADP'),
#   ('Bermuda', 'NOUN'),
#   (',', '.'),
#   ('where', 'ADV'),
#   ('the', 'DET'),
#   ('Supreme', 'NOUN'),
#   ('Court', 'NOUN'),
#   ('has', 'VERB'),
#   ('temporarily', 'ADV'),
#   ('barred', 'VERB'),
#   ('Sea', 'NOUN'),
#   ('Containers', 'NOUN'),
#   ('from', 'ADP'),
#   ('*-3', 'X'),
#   ('buying', 'VERB'),
#   ('back', 'PRT'),
#   ('its', 'PRON'),
#   ('own', 'ADJ'),
#   ('stock', 'NOUN'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('case', 'NOUN'),
#   ('brought', 'VERB'),
#   ('*', 'X'),
#   ('by', 'ADP'),
#   ('Stena', 'NOUN'),
#   ('and', 'CONJ'),
#   ('Tiphook', 'NOUN'),
#   ('*T*-1', 'X'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('Robert', 'NOUN'),
#   ('Whiting', 'NOUN'),
#   ("'s", 'PRT'),
#   ('``', '.'),
#   ('You', 'PRON'),
#   ('Gotta', 'NOUN'),
#   ('Have', 'NOUN'),
#   ('Wa', '.'),
#   ("''", '.'),
#   ('-LRB-', '.'),
#   ('Macmillan', 'NOUN'),
#   (',', '.'),
#   ('339', 'NUM'),
#   ('pages', 'NOUN'),
#   (',', '.'),
#   ('$', '.'),
#   ('17.95', 'NUM'),
#   ('*U*', 'X'),
#   ('-RRB-', '.'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Beatles', 'NOUN'),
#   ('give', 'VERB'),
#   ('way', 'NOUN'),
#   ('to', 'PRT'),
#   ('baseball', 'NOUN'),
#   (',', '.'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('Nipponese', 'ADJ'),
#   ('version', 'NOUN'),
#   ('0', 'X'),
#   ('we', 'PRON'),
#   ('would', 'VERB'),
#   ('be', 'VERB'),
#   ('hard', 'ADV'),
#   ('put', 'VERB'),
#   ('*-2', 'X'),
#   ('to', 'PRT'),
#   ('call', 'VERB'),
#   ('*T*-1', 'X'),
#   ('a', 'DET'),
#   ('``', '.'),
#   ('game', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('Hammacher', 'NOUN'),
#   ('Schlemmer', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Co.', 'NOUN'),
#   ('offers', 'VERB'),
#   ('a', 'DET'),
#   ('fiber-optic', 'ADJ'),
#   ('Christmas', 'NOUN'),
#   ('tree', 'NOUN'),
#   ('that', 'DET'),
#   ('*T*-1', 'X'),
#   ('eliminates', 'VERB'),
#   ('the', 'DET'),
#   ('need', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('string', 'VERB'),
#   ('lights', 'NOUN'),
#   ('.', '.')],
#  [('That', 'DET'),
#   ('fund', 'NOUN'),
#   ('was', 'VERB'),
#   ('put', 'VERB'),
#   ('*-41', 'X'),
#   ('together', 'PRT'),
#   ('by', 'ADP'),
#   ('Blackstone', 'NOUN'),
#   ('Group', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('investment', 'NOUN'),
#   ('bank', 'NOUN'),
#   ('.', '.')],
#  [('In', 'ADP'),
#   ('composite', 'ADJ'),
#   ('trading', 'NOUN'),
#   ('on', 'ADP'),
#   ('the', 'DET'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('Stock', 'NOUN'),
#   ('Exchange', 'NOUN'),
#   (',', '.'),
#   ('Telerate', 'NOUN'),
#   ('shares', 'NOUN'),
#   ('closed', 'VERB'),
#   ('at', 'ADP'),
#   ('$', '.'),
#   ('19.50', 'NUM'),
#   ('*U*', 'X'),
#   (',', '.'),
#   ('up', 'ADV'),
#   ('12.5', 'NUM'),
#   ('cents', 'NOUN'),
#   ('.', '.')],
#  [('Propaganda', 'NOUN'),
#   ('is', 'VERB'),
#   ('just', 'ADV'),
#   ('information', 'NOUN'),
#   ('0', 'X'),
#   ('*T*-1', 'X'),
#   ('to', 'PRT'),
#   ('support', 'VERB'),
#   ('a', 'DET'),
#   ('viewpoint', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('the', 'DET'),
#   ('beauty', 'NOUN'),
#   ('of', 'ADP'),
#   ('a', 'DET'),
#   ('democracy', 'NOUN'),
#   ('is', 'VERB'),
#   ('that', 'ADP'),
#   ('it', 'PRON'),
#   ('enables', 'VERB'),
#   ('you', 'PRON'),
#   ('to', 'PRT'),
#   ('hear', 'VERB'),
#   ('or', 'CONJ'),
#   ('read', 'VERB'),
#   ('every', 'DET'),
#   ('viewpoint', 'NOUN'),
#   ('and', 'CONJ'),
#   ('then', 'ADV'),
#   ('make', 'VERB'),
#   ('up', 'PRT'),
#   ('your', 'PRON'),
#   ('own', 'ADJ'),
#   ('mind', 'NOUN'),
#   ('on', 'ADP'),
#   ('an', 'DET'),
#   ('issue', 'NOUN'),
#   ('.', '.')],
#  [('Last', 'ADJ'),
#   ('October', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('company', 'NOUN'),
#   ('also', 'ADV'),
#   ('bought', 'VERB'),
#   ('a', 'DET'),
#   ('wheel-loader', 'ADJ'),
#   ('manufacturing', 'NOUN'),
#   ('plant', 'NOUN'),
#   ('in', 'ADP'),
#   ('Heidelberg', 'NOUN'),
#   (',', '.'),
#   ('West', 'NOUN'),
#   ('Germany', 'NOUN'),
#   (',', '.'),
#   ('from', 'ADP'),
#   ('Dresser', 'NOUN'),
#   ('.', '.')],
#  [('Michael', 'NOUN'),
#   ('R.', 'NOUN'),
#   ('Bromwich', 'NOUN'),
#   (',', '.'),
#   ('a', 'DET'),
#   ('member', 'NOUN'),
#   ('since', 'ADP'),
#   ('January', 'NOUN'),
#   ('1987', 'NUM'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('three-lawyer', 'ADJ'),
#   ('trial', 'NOUN'),
#   ('team', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('prosecution', 'NOUN'),
#   ('of', 'ADP'),
#   ('Oliver', 'NOUN'),
#   ('North', 'NOUN'),
#   (',', '.'),
#   ('became', 'VERB'),
#   ('a', 'DET'),
#   ('partner', 'NOUN'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('Washington', 'NOUN'),
#   (',', '.'),
#   ('D.C.', 'NOUN'),
#   (',', '.'),
#   ('office', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('520-lawyer', 'ADJ'),
#   ('firm', 'NOUN'),
#   ('.', '.')],
#  [('Giant', 'NOUN'),
#   ('Group', 'NOUN'),
#   ('is', 'VERB'),
#   ('led', 'VERB'),
#   ('*-1', 'X'),
#   ('by', 'ADP'),
#   ('three', 'NUM'),
#   ('Rally', 'NOUN'),
#   ("'s", 'PRT'),
#   ('directors', 'NOUN'),
#   (',', '.'),
#   ('Burt', 'NOUN'),
#   ('Sugarman', 'NOUN'),
#   (',', '.'),
#   ('James', 'NOUN'),
#   ('M.', 'NOUN'),
#   ('Trotter', 'NOUN'),
#   ('III', 'NOUN'),
#   ('and', 'CONJ'),
#   ('William', 'NOUN'),
#   ('E.', 'NOUN'),
#   ('Trotter', 'NOUN'),
#   ('II', 'NOUN'),
#   (',', '.'),
#   ('who', 'PRON'),
#   ('earlier', 'ADV'),
#   ('this', 'DET'),
#   ('month', 'NOUN'),
#   ('*T*-2', 'X'),
#   ('indicated', 'VERB'),
#   ('0', 'X'),
#   ('they', 'PRON'),
#   ('had', 'VERB'),
#   ('a', 'DET'),
#   ('42.5', 'NUM'),
#   ('%', 'NOUN'),
#   ('stake', 'NOUN'),
#   ('in', 'ADP'),
#   ('Rally', 'NOUN'),
#   ("'s", 'PRT'),
#   ('and', 'CONJ'),
#   ('planned', 'VERB'),
#   ('*-3', 'X'),
#   ('to', 'PRT'),
#   ('seek', 'VERB'),
#   ('a', 'DET'),
#   ('majority', 'NOUN'),
#   ('of', 'ADP'),
#   ('seats', 'NOUN'),
#   ('on', 'ADP'),
#   ('Rally', 'NOUN'),
#   ("'s", 'PRT'),
#   ('nine-member', 'ADJ'),
#   ('board', 'NOUN'),
#   ('.', '.')],
#  [('Billings', 'NOUN'),
#   ('*ICH*-3', 'X'),
#   ('were', 'VERB'),
#   ("n't", 'ADV'),
#   ('disclosed', 'VERB'),
#   ('*-1', 'X'),
#   ('for', 'ADP'),
#   ('the', 'DET'),
#   ('small', 'ADJ'),
#   ('account', 'NOUN'),
#   (',', '.'),
#   ('which', 'DET'),
#   ('*T*-155', 'X'),
#   ('had', 'VERB'),
#   ('been', 'VERB'),
#   ('serviced', 'VERB'),
#   ('*-2', 'X'),
#   ('at', 'ADP'),
#   ('Young', 'NOUN'),
#   ('&', 'CONJ'),
#   ('Rubicam', 'NOUN'),
#   (',', '.'),
#   ('New', 'NOUN'),
#   ('York', 'NOUN'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Stronach', 'NOUN'),
#   ('will', 'VERB'),
#   ('direct', 'VERB'),
#   ('an', 'DET'),
#   ('effort', 'NOUN'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('reduce', 'VERB'),
#   ('overhead', 'NOUN'),
#   ('and', 'CONJ'),
#   ('curb', 'VERB'),
#   ('capital', 'NOUN'),
#   ('spending', 'NOUN'),
#   ('``', '.'),
#   ('until', 'ADP'),
#   ('a', 'DET'),
#   ('more', 'ADV'),
#   ('satisfactory', 'ADJ'),
#   ('level', 'NOUN'),
#   ('of', 'ADP'),
#   ('profit', 'NOUN'),
#   ('is', 'VERB'),
#   ('achieved', 'VERB'),
#   ('and', 'CONJ'),
#   ('maintained', 'VERB'),
#   ('*-1', 'X'),
#   (',', '.'),
#   ("''", '.'),
#   ('Magna', 'NOUN'),
#   ('said', 'VERB'),
#   ('0', 'X'),
#   ('*T*-2', 'X'),
#   ('.', '.')],
#  [('As', 'ADP'),
#   ('Mr.', 'NOUN'),
#   ('Whiting', 'NOUN'),
#   ('describes', 'VERB'),
#   ('it', 'PRON'),
#   (',', '.'),
#   ('Nipponese', 'ADJ'),
#   ('baseball', 'NOUN'),
#   ('is', 'VERB'),
#   ('a', 'DET'),
#   ('``', '.'),
#   ('mirror', 'NOUN'),
#   ('of', 'ADP'),
#   ('Japan', 'NOUN'),
#   ("'s", 'PRT'),
#   ('fabled', 'ADJ'),
#   ('virtues', 'NOUN'),
#   ('of', 'ADP'),
#   ('hard', 'ADJ'),
#   ('work', 'NOUN'),
#   ('and', 'CONJ'),
#   ('harmony', 'NOUN'),
#   ('.', '.'),
#   ("''", '.')],
#  [('There', 'DET'),
#   ('is', 'VERB'),
#   ('$', '.'),
#   ('81.8', 'NUM'),
#   ('million', 'NUM'),
#   ('*U*', 'X'),
#   ('of', 'ADP'),
#   ('7.20', 'NUM'),
#   ('%', 'NOUN'),
#   ('term', 'NOUN'),
#   ('bonds', 'NOUN'),
#   ('due', 'ADJ'),
#   ('2009', 'NUM'),
#   ('priced', 'VERB'),
#   ('*', 'X'),
#   ('at', 'ADP'),
#   ('99', 'NUM'),
#   ('1\\/4', 'NUM'),
#   ('*', 'X'),
#   ('to', 'PRT'),
#   ('yield', 'VERB'),
#   ('7.272', 'NUM'),
#   ('%', 'NOUN'),
#   ('.', '.')]]

# %%
# tagging the test sentences using the vanilla veterbi
start = time.time()
tagged_seq_vanilla = Viterbi(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
print(tagged_seq_vanilla)
# Out:
# Time taken in seconds:  1004.010059595108
# [('Mr.', 'NOUN'), ('Trump', 'NOUN'), ('withdrew', 'ADJ'), ('a', 'DET'), ('$', '.'), ('120-a-share', 'ADJ'), ('*U*', 'X'), ('bid', 'VERB'), ('last', 'ADJ'), ('month', 'NOUN'), ('.', '.'), ('Japan', 'NOUN'), ("'s", 'PRT'), ('Finance', 'NOUN'), ('Ministry', 'NOUN'), ('had', 'VERB'), ('set', 'VERB'), ('up', 'ADV'), ('mechanisms', 'ADJ'), ('0', 'X'), ('*-1', 'X'), ('to', 'PRT'), ('limit', 'NOUN'), ('how', 'ADV'), ('far', 'ADV'), ('futures', 'NOUN'), ('prices', 'NOUN'), ('could', 'VERB'), ('fall', 'VERB'), ('*T*-2', 'X'), ('in', 'ADP'), ('a', 'DET'), ('single', 'ADJ'), ('session', 'NOUN'), ('and', 'CONJ'), ('*-1', 'X'), ('to', 'PRT'), ('give', 'VERB'), ('market', 'NOUN'), ('operators', 'NOUN'), ('the', 'DET'), ('authority', 'NOUN'), ('*', 'X'), ('to', 'PRT'), ('suspend', 'VERB'), ('trading', 'NOUN'), ('in', 'ADP'), ('futures', 'NOUN'), ('at', 'ADP'), ('any', 'DET'), ('time', 'NOUN'), ('.', '.'), ('I', 'PRON'), ('have', 'VERB'), ('a', 'DET'), ('right', 'NOUN'), ('*-1', 'X'), ('to', 'PRT'), ('print', 'VERB'), ('those', 'DET'), ('scripts', 'NOUN'), ('if', 'ADP'), ('I', 'PRON'), ('go', 'VERB'), ('there', 'DET'), ('and', 'CONJ'), ('laboriously', 'ADJ'), ('--', '.'), ('but', 'CONJ'), ('no', 'DET'), ('longer', 'ADJ'), ('surreptitiously', 'ADJ'), ('--', '.'), ('copy', 'VERB'), ('them', 'PRON'), ('out', 'PRT'), ('in', 'ADP'), ('long', 'ADJ'), ('hand', 'NOUN'), ('.', '.'), ('*', 'X'), ('Take', 'VERB'), ('Lake', 'NOUN'), ('Vineyard', 'NOUN'), ('Cabernet', 'NOUN'), ('from', 'ADP'), ('Diamond', 'NOUN'), ('Creek', 'NOUN'), ('.', '.'), ('And', 'CONJ'), ('unlike', 'ADJ'), ('some', 'DET'), ('trays', 'NOUN'), (',', '.'), ('there', 'DET'), ("'s", 'VERB'), ('no', 'DET'), ('place', 'NOUN'), ('for', 'ADP'), ('food', 'NOUN'), ('.', '.'), ('Standard', 'NOUN'), ('&', 'CONJ'), ('Poor', 'NOUN'), ("'s", 'PRT'), ('Corp.', 'NOUN'), ('says', 'VERB'), ('0', 'X'), ('First', 'NOUN'), ('Boston', 'NOUN'), (',', '.'), ('Shearson', 'NOUN'), ('and', 'CONJ'), ('Drexel', 'NOUN'), ('Burnham', 'NOUN'), ('Lambert', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('in', 'ADP'), ('particular', 'ADJ'), (',', '.'), ('are', 'VERB'), ('likely', 'ADJ'), ('*-1', 'X'), ('to', 'PRT'), ('have', 'VERB'), ('difficulty', 'ADJ'), ('*-2', 'X'), ('shoring', 'ADJ'), ('up', 'PRT'), ('their', 'PRON'), ('credit', 'NOUN'), ('standing', 'NOUN'), ('in', 'ADP'), ('months', 'NOUN'), ('ahead', 'ADV'), ('.', '.'), ('Also', 'ADV'), (',', '.'), ('Big', 'NOUN'), ('Board', 'NOUN'), ('Chairman', 'NOUN'), ('Phelan', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('he', 'PRON'), ('would', 'VERB'), ('support', 'VERB'), ('SEC', 'NOUN'), ('halts', 'NOUN'), ('of', 'ADP'), ('program', 'NOUN'), ('trading', 'NOUN'), ('during', 'ADP'), ('market', 'NOUN'), ('crises', 'ADJ'), ('but', 'CONJ'), ('not', 'ADV'), ('any', 'DET'), ('revival', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('``', '.'), ('collar', 'NOUN'), ("''", '.'), ('on', 'ADP'), ('trading', 'NOUN'), ('.', '.'), ('Columbia', 'NOUN'), ('Savings', 'NOUN'), ('&', 'CONJ'), ('Loan', 'NOUN'), ('-LRB-', '.'), ('NYSE', 'ADJ'), (';', '.'), ('Symbol', 'ADJ'), (':', '.'), ('CSV', 'ADJ'), ('-RRB-', '.'), ('I', 'PRON'), ('say', 'VERB'), ('``', '.'), ('*', 'X'), ('contained', 'VERB'), ('dialogue', 'NOUN'), ("''", '.'), ('because', 'ADP'), ('``', '.'), ('Sidewalk', 'NOUN'), ('Stories', 'NOUN'), ("''", '.'), ('is', 'VERB'), ("n't", 'ADV'), ('really', 'ADV'), ('silent', 'ADJ'), ('at', 'ADP'), ('all', 'DET'), ('.', '.'), ('In', 'ADP'), ('his', 'PRON'), ('return', 'VERB'), ('toast', 'NOUN'), ('to', 'PRT'), ('Mr.', 'NOUN'), ('Nixon', 'NOUN'), (',', '.'), ('Mr.', 'NOUN'), ('Yang', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('the', 'DET'), ('relationship', 'NOUN'), ('had', 'VERB'), ('reached', 'VERB'), ('a', 'DET'), ('``', '.'), ('stalemate', 'NOUN'), ('.', '.'), ("''", '.'), ('Municipal', 'NOUN'), ('bonds', 'NOUN'), ('were', 'VERB'), ('mostly', 'ADV'), ('unchanged', 'ADJ'), ('to', 'PRT'), ('up', 'ADV'), ('1\\/8', 'NUM'), ('point', 'NOUN'), ('in', 'ADP'), ('light', 'ADJ'), (',', '.'), ('cautious', 'ADJ'), ('t ...

# %%
# accuracy
check_vanilla = [i for i, j in zip(tagged_seq_vanilla, test_run_base) if i == j] 
accuracy_vanilla = len(check_vanilla)/len(tagged_seq_vanilla)
accuracy_vanilla
# Out:
# 0.927664718920008

# %%
# Finiding the incorrectly tagged cases
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq_vanilla, test_run_base)) if j[0]!=j[1]]

# %%
incorrect_tagged_cases
# Out:
# [[('Trump', 'NOUN'), (('withdrew', 'ADJ'), ('withdrew', 'VERB'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('set', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('up', 'PRT'), (('mechanisms', 'ADJ'), ('mechanisms', 'NOUN'))],
#  [('to', 'PRT'), (('limit', 'NOUN'), ('limit', 'VERB'))],
#  [('how', 'ADV'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('go', 'VERB'), (('there', 'DET'), ('there', 'ADV'))],
#  [('and', 'CONJ'), (('laboriously', 'ADJ'), ('laboriously', 'ADV'))],
#  [('but', 'CONJ'), (('no', 'DET'), ('no', 'ADV'))],
#  [('longer', 'ADJ'), (('surreptitiously', 'ADJ'), ('surreptitiously', 'ADV'))],
#  [('And', 'CONJ'), (('unlike', 'ADJ'), ('unlike', 'ADP'))],
#  [('have', 'VERB'), (('difficulty', 'ADJ'), ('difficulty', 'NOUN'))],
#  [('*-2', 'X'), (('shoring', 'ADJ'), ('shoring', 'VERB'))],
#  [('market', 'NOUN'), (('crises', 'ADJ'), ('crises', 'NOUN'))],
#  [('-LRB-', '.'), (('NYSE', 'ADJ'), ('NYSE', 'NOUN'))],
#  [(';', '.'), (('Symbol', 'ADJ'), ('Symbol', 'NOUN'))],
#  [(':', '.'), (('CSV', 'ADJ'), ('CSV', 'NOUN'))],
#  [('his', 'PRON'), (('return', 'VERB'), ('return', 'NOUN'))],
#  [("''", '.'), (('Municipal', 'NOUN'), ('Municipal', 'ADJ'))],
#  [('took', 'VERB'), (('further', 'ADV'), ('further', 'ADJ'))],
#  [('further', 'ADJ'), (('steps', 'VERB'), ('steps', 'NOUN'))],
#  [('thing', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('market', 'NOUN'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('right', 'ADV'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('is', 'VERB'), (('merchandising', 'ADJ'), ('merchandising', 'NOUN'))],
#  [('E.', 'NOUN'), (('Guigal', 'ADJ'), ('Guigal', 'NOUN'))],
#  [('1982', 'NUM'), (('Cote', 'ADJ'), ('Cote', 'NOUN'))],
#  [('Cote', 'NOUN'), (('Rotie', 'ADJ'), ('Rotie', 'NOUN'))],
#  [('La', 'NOUN'), (('Landonne', 'ADJ'), ('Landonne', 'NOUN'))],
#  [('hefty', 'ADJ'), (('dashes', 'ADJ'), ('dashes', 'NOUN'))],
#  [('new', 'ADJ'), (('twist', 'ADJ'), ('twist', 'NOUN'))],
#  [('bought', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('may', 'VERB'), (('challenge', 'NOUN'), ('challenge', 'VERB'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('it', 'PRON'), (('all', 'DET'), ('all', 'ADV'))],
#  [('*T*-1', 'X'), (('Laura', 'ADJ'), ('Laura', 'NOUN'))],
#  [('Laura', 'NOUN'), (('Dobson', 'ADJ'), ('Dobson', 'NOUN'))],
#  [('a', 'DET'), (('freshman', 'ADJ'), ('freshman', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-90', 'ADJ'), ('*T*-90', 'X'))],
#  [('an', 'DET'), (('individual', 'ADJ'), ('individual', 'NOUN'))],
#  [('active', 'ADJ'), (('55-year-old', 'ADJ'), ('55-year-old', 'NOUN'))],
#  [('may', 'VERB'), (('care', 'NOUN'), ('care', 'VERB'))],
#  [('about', 'ADP'), (('Senior', 'ADJ'), ('Senior', 'NOUN'))],
#  [('a', 'DET'), (('75-year-old', 'ADJ'), ('75-year-old', 'NUM'))],
#  [('may', 'VERB'), (('care', 'NOUN'), ('care', 'VERB'))],
#  [('very', 'ADV'), (('complicated', 'ADJ'), ('complicated', 'VERB'))],
#  [('been', 'VERB'), (('firmly', 'ADJ'), ('firmly', 'ADV'))],
#  [('firmly', 'ADV'), (('set', 'NOUN'), ('set', 'VERB'))],
#  [('an', 'DET'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('the', 'DET'), (('charm', 'ADJ'), ('charm', 'NOUN'))],
#  [('this', 'DET'), (('engaging', 'VERB'), ('engaging', 'ADJ'))],
#  [('*', 'X'), (('recognizing', 'ADJ'), ('recognizing', 'VERB'))],
#  [('contemporary', 'ADJ'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('American', 'ADJ'), (('lore', 'ADJ'), ('lore', 'NOUN'))],
#  [('which', 'DET'), (('*T*-112', 'ADJ'), ('*T*-112', 'X'))],
#  [('industrial', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [(':', '.'), (('Can', 'ADJ'), ('Can', 'VERB'))],
#  [('hard-charging', 'ADJ'), (('Teddy', 'ADJ'), ('Teddy', 'NOUN'))],
#  [('Teddy', 'NOUN'), (('Roosevelt', 'ADJ'), ('Roosevelt', 'NOUN'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('to', 'PRT'), (('bolster', 'ADJ'), ('bolster', 'VERB'))],
#  [('of', 'ADP'), (('excise', 'VERB'), ('excise', 'ADJ'))],
#  [('presented', 'VERB'), (('claims', 'VERB'), ('claims', 'NOUN'))],
#  [('Norman', 'NOUN'), (('Ricken', 'ADJ'), ('Ricken', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('of', 'ADP'), (('Toys', 'ADJ'), ('Toys', 'NOUN'))],
#  [('``', '.'), (('R', 'ADJ'), ('R', 'NOUN'))],
#  [("''", '.'), (('Us', 'ADJ'), ('Us', 'NOUN'))],
#  [('Frederick', 'NOUN'), (('Deane', 'ADJ'), ('Deane', 'NOUN'))],
#  [('of', 'ADP'), (('Signet', 'ADJ'), ('Signet', 'NOUN'))],
#  [('was', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('64-year-old', 'ADJ'), (('Derek', 'ADJ'), ('Derek', 'NOUN'))],
#  [('opening', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('wines', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-168', 'ADJ'), ('*T*-168', 'X'))],
#  [('*T*-168', 'X'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [(':', '.'), (('Gilts', 'ADJ'), ('Gilts', 'NOUN'))],
#  [(',', '.'), (('retraced', 'ADJ'), ('retraced', 'VERB'))],
#  [('to', 'PRT'), (('end', 'NOUN'), ('end', 'VERB'))],
#  [('.', '.'), (('J.P.', 'ADJ'), ('J.P.', 'NOUN'))],
#  [('J.P.', 'NOUN'), (('Bolduc', 'ADJ'), ('Bolduc', 'NOUN'))],
#  [('a', 'DET'), (('83.4', 'ADJ'), ('83.4', 'NUM'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('&', 'CONJ'), (('Rubicam', 'ADJ'), ('Rubicam', 'NOUN'))],
#  [('of', 'ADP'), (('Landor', 'ADJ'), ('Landor', 'NOUN'))],
#  [('Francisco', 'NOUN'),
#   (('identity-management', 'ADJ'), ('identity-management', 'NOUN'))],
#  [('.', '.'), (('Yet', 'CONJ'), ('Yet', 'ADV'))],
#  [('Marie-Louise', 'NOUN'), (('Giraud', 'ADJ'), ('Giraud', 'NOUN'))],
#  [('historical', 'ADJ'), (('significance', 'ADJ'), ('significance', 'NOUN'))],
#  [("'s", 'PRT'), (('hypocrisy', 'ADJ'), ('hypocrisy', 'NOUN'))],
#  [('on', 'ADP'), (('Trans', 'ADJ'), ('Trans', 'NOUN'))],
#  [('.', '.'), (('Guarantee', 'ADJ'), ('Guarantee', 'NOUN'))],
#  [('plus', 'CONJ'), (('accrued', 'ADJ'), ('accrued', 'VERB'))],
#  [('12-point', 'ADJ'),
#   (('circuit-breaker', 'ADJ'), ('circuit-breaker', 'NOUN'))],
#  [('circuit-breaker', 'NOUN'),
#   (('aggravated', 'ADJ'), ('aggravated', 'VERB'))],
#  [('*-1', 'X'), (('directing', 'ADJ'), ('directing', 'VERB'))],
#  [('additional', 'ADJ'), (('selling', 'NOUN'), ('selling', 'VERB'))],
#  [('has', 'VERB'), (('wedded', 'ADJ'), ('wedded', 'VERB'))],
#  [('to', 'PRT'), (('trash', 'ADJ'), ('trash', 'VERB'))],
#  [('at', 'ADP'), (('60.36', 'ADJ'), ('60.36', 'NUM'))],
#  [('companies', 'NOUN'), (('bankroll', 'ADJ'), ('bankroll', 'VERB'))],
#  [('frequently', 'ADV'), (('putting', 'ADJ'), ('putting', 'VERB'))],
#  [('touch', 'VERB'), (('*T*-191', 'ADJ'), ('*T*-191', 'X'))],
#  [('.', '.'), (('Performing', 'ADJ'), ('Performing', 'VERB'))],
#  [('RMS', 'NOUN'), (('distributes', 'ADJ'), ('distributes', 'VERB'))],
#  [('and', 'CONJ'), (('produces', 'ADJ'), ('produces', 'VERB'))],
#  [('power', 'NOUN'), (('supplies', 'VERB'), ('supplies', 'NOUN'))],
#  [('plastic', 'ADJ'), (('literature', 'ADJ'), ('literature', 'NOUN'))],
#  [('literature', 'NOUN'), (('displays', 'ADJ'), ('displays', 'NOUN'))],
#  [('which', 'DET'), (('*T*-174', 'ADJ'), ('*T*-174', 'X'))],
#  [('operates', 'VERB'), (('hotels', 'ADJ'), ('hotels', 'NOUN'))],
#  [('rights', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-175', 'ADJ'), ('*T*-175', 'X'))],
#  [('of', 'ADP'), (('Child', 'ADJ'), ('Child', 'NOUN'))],
#  [('Anne', 'NOUN'), (('Dolan', 'ADJ'), ('Dolan', 'NOUN'))],
#  [(',', '.'), (('restored', 'ADJ'), ('restored', 'VERB'))],
#  [('been', 'VERB'), (('limping', 'ADJ'), ('limping', 'VERB'))],
#  [('on', 'ADP'), (('limited', 'ADJ'), ('limited', 'VERB'))],
#  [('its', 'PRON'), (('accomplishments', 'ADJ'), ('accomplishments', 'NOUN'))],
#  [('.', '.'), (('9.82', 'ADJ'), ('9.82', 'NUM'))],
#  [('rate', 'NOUN'), (('capped', 'VERB'), ('capped', 'ADJ'))],
#  [('the', 'DET'), (('referral', 'ADJ'), ('referral', 'NOUN'))],
#  [('.', '.'), (('Financially', 'ADJ'), ('Financially', 'ADV'))],
#  [('its', 'PRON'), (('moments', 'ADJ'), ('moments', 'NOUN'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('be', 'VERB'), (('scared', 'ADJ'), ('scared', 'VERB'))],
#  [('*-83', 'X'), (('away', 'PRT'), ('away', 'ADV'))],
#  [('Poore', 'NOUN'), (('replies', 'NOUN'), ('replies', 'VERB'))],
#  [('gigantic', 'ADJ'), (('crapshoot', 'ADJ'), ('crapshoot', 'NOUN'))],
#  [("''", '.'), (('Dreyfus', 'ADJ'), ('Dreyfus', 'NOUN'))],
#  [('Dreyfus', 'NOUN'), (('World-Wide', 'ADJ'), ('World-Wide', 'NOUN'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('9.37', 'ADJ'), ('9.37', 'NUM'))],
#  [('from', 'ADP'), (('9.45', 'ADJ'), ('9.45', 'NUM'))],
#  [('week', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('of', 'ADP'), (('rusted', 'ADJ'), ('rusted', 'VERB'))],
#  [('oil', 'NOUN'), (('drums', 'ADJ'), ('drums', 'NOUN'))],
#  [('drums', 'NOUN'), (('swim', 'ADJ'), ('swim', 'VERB'))],
#  [('voice', 'NOUN'), (('purrs', 'ADJ'), ('purrs', 'VERB'))],
#  [('the', 'DET'), (('neighbors', 'ADJ'), ('neighbors', 'NOUN'))],
#  [('her', 'PRON'), (('motives', 'ADJ'), ('motives', 'NOUN'))],
#  [('were', 'VERB'), (('correct', 'VERB'), ('correct', 'ADJ'))],
#  [('by', 'ADP'), (('Thrall', 'ADJ'), ('Thrall', 'NOUN'))],
#  [('held', 'VERB'), (('Duchossois', 'ADJ'), ('Duchossois', 'NOUN'))],
#  [(',', '.'), (('Elmhurst', 'ADJ'), ('Elmhurst', 'NOUN'))],
#  [('*-1', 'X'), (('needing', 'ADJ'), ('needing', 'VERB'))],
#  [('By', 'ADP'), (('1997', 'ADJ'), ('1997', 'NUM'))],
#  [('remaining', 'VERB'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('be', 'VERB'), (('outlawed', 'ADJ'), ('outlawed', 'VERB'))],
#  [('*-2', 'X'), (('punishing', 'ADJ'), ('punishing', 'VERB'))],
#  [('or', 'CONJ'), (('retaliating', 'ADJ'), ('retaliating', 'VERB'))],
#  [('when', 'ADV'), (('trading', 'VERB'), ('trading', 'NOUN'))],
#  [('trading', 'NOUN'), (('resumes', 'ADJ'), ('resumes', 'VERB'))],
#  [('futures', 'NOUN'), (('fall', 'NOUN'), ('fall', 'VERB'))],
#  [("'s", 'PRT'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('team', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('Mercury', 'NOUN'), (('Sable', 'ADJ'), ('Sable', 'NOUN'))],
#  [('*-2', 'X'), (('experiencing', 'ADJ'), ('experiencing', 'VERB'))],
#  [('too', 'ADV'), (('low', 'ADJ'), ('low', 'ADV'))],
#  [('Younkers', 'NOUN'), (('rang', 'ADJ'), ('rang', 'VERB'))],
#  [('$', '.'), (('313', 'ADJ'), ('313', 'NUM'))],
#  [('*', 'X'), (('Getting', 'ADJ'), ('Getting', 'VERB'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('Hahn', 'NOUN'), (('attributes', 'ADJ'), ('attributes', 'VERB'))],
#  [('the', 'DET'), (('philosophy', 'ADJ'), ('philosophy', 'NOUN'))],
#  [('*', 'X'), (('concentrating', 'ADJ'), ('concentrating', 'VERB'))],
#  [('to', 'PRT'), (('disseminate', 'ADJ'), ('disseminate', 'VERB'))],
#  [('a', 'DET'), (('memo', 'ADJ'), ('memo', 'NOUN'))],
#  [('prime', 'ADJ'), (('borrowing', 'NOUN'), ('borrowing', 'VERB'))],
#  [('--', '.'), (('and', 'CONJ'), ('and', 'ADJ'))],
#  [('having', 'VERB'), (('borrowed', 'ADJ'), ('borrowed', 'VERB'))],
#  [('$', '.'), (('3.4', 'ADJ'), ('3.4', 'NUM'))],
#  [('the', 'DET'), (('Equal', 'ADJ'), ('Equal', 'NOUN'))],
#  [('Equal', 'NOUN'), (('Employment', 'ADJ'), ('Employment', 'NOUN'))],
#  [('Employment', 'NOUN'), (('Opportunity', 'ADJ'), ('Opportunity', 'NOUN'))],
#  [('Ms.', 'NOUN'), (('Kirkpatrick', 'ADJ'), ('Kirkpatrick', 'NOUN'))],
#  [('a', 'DET'), (('Hamilton', 'ADJ'), ('Hamilton', 'NOUN'))],
#  [('0', 'X'), (('most', 'ADV'), ('most', 'ADJ'))],
#  [('and', 'CONJ'), (('257', 'ADJ'), ('257', 'NUM'))],
#  [('shut', 'VERB'), (('down', 'ADV'), ('down', 'PRT'))],
#  [('the', 'DET'), (('equivalent', 'ADJ'), ('equivalent', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('the', 'DET'), (('hysteria', 'ADJ'), ('hysteria', 'NOUN'))],
#  [('payable', 'ADJ'), (('Jan.', 'ADJ'), ('Jan.', 'NOUN'))],
#  [('Gulf', 'NOUN'), (('spurns', 'ADJ'), ('spurns', 'VERB'))],
#  [('morale-damaging', 'ADJ'), (('public', 'NOUN'), ('public', 'ADJ'))],
#  [('*U*', 'X'), (('gain', 'VERB'), ('gain', 'NOUN'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('to', 'PRT'), (('apologize', 'ADJ'), ('apologize', 'VERB'))],
#  [('.', '.'), (('Ad', 'ADJ'), ('Ad', 'NOUN'))],
#  [('Ad', 'NOUN'), (('Notes', 'ADJ'), ('Notes', 'NOUN'))],
#  [('Malcolm', 'NOUN'), (('Davies', 'ADJ'), ('Davies', 'NOUN'))],
#  [('Trading', 'NOUN'), (('Alliance', 'ADJ'), ('Alliance', 'NOUN'))],
#  [('On', 'ADP'), (('weekends', 'ADJ'), ('weekends', 'NOUN'))],
#  [('to', 'PRT'), (('prepare', 'ADJ'), ('prepare', 'VERB'))],
#  [('study', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('to', 'PRT'), (('polish', 'ADJ'), ('polish', 'VERB'))],
#  [('*', 'X'), (('Possibly', 'ADJ'), ('Possibly', 'ADV'))],
#  [('offsetting', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Output', 'ADJ'), ('Output', 'NOUN'))],
#  [('be', 'VERB'), (('gradually', 'ADJ'), ('gradually', 'ADV'))],
#  [('it', 'PRON'), (('reaches', 'ADJ'), ('reaches', 'VERB'))],
#  [('test-coaching', 'ADJ'), (('workbooks', 'ADJ'), ('workbooks', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('consumer', 'NOUN'), (('banking', 'NOUN'), ('banking', 'VERB'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('previously', 'ADV'), (('spurned', 'ADJ'), ('spurned', 'VERB'))],
#  [('legislation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*-1', 'X'), (('Funded', 'ADJ'), ('Funded', 'VERB'))],
#  [('from', 'ADP'), (('Tokio', 'ADJ'), ('Tokio', 'NOUN'))],
#  [('medical', 'ADJ'), (('protocols', 'ADJ'), ('protocols', 'NOUN'))],
#  [('the', 'DET'), (('junk-bond', 'NOUN'), ('junk-bond', 'ADJ'))],
#  [('*', 'X'), (('lessening', 'ADJ'), ('lessening', 'VERB'))],
#  [('the', 'DET'), (('likelihood', 'ADJ'), ('likelihood', 'NOUN'))],
#  [('they', 'PRON'), (('own', 'ADJ'), ('own', 'VERB'))],
#  [('would', 'VERB'), (('assess', 'ADJ'), ('assess', 'VERB'))],
#  [('and', 'CONJ'), (('apparel', 'ADJ'), ('apparel', 'NOUN'))],
#  [('trade', 'NOUN'), (('agreements', 'ADJ'), ('agreements', 'NOUN'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('to', 'PRT'), (('500,004', 'ADJ'), ('500,004', 'NUM'))],
#  [('Japan', 'NOUN'), (('Automobile', 'ADJ'), ('Automobile', 'NOUN'))],
#  [('police', 'NOUN'), (('escort', 'ADJ'), ('escort', 'NOUN'))],
#  [(',', '.'), (('busloads', 'ADJ'), ('busloads', 'NOUN'))],
#  [('their', 'PRON'), (('wives', 'ADJ'), ('wives', 'NOUN'))],
#  [('wives', 'NOUN'), (('raced', 'ADJ'), ('raced', 'VERB'))],
#  [('Motor', 'NOUN'), (('Speedway', 'ADJ'), ('Speedway', 'NOUN'))],
#  [('by', 'ADP'), (('traffic', 'ADJ'), ('traffic', 'NOUN'))],
#  [('red', 'ADJ'), (('lights', 'ADJ'), ('lights', 'NOUN'))],
#  [('architect', 'NOUN'), (('Julia', 'ADJ'), ('Julia', 'NOUN'))],
#  [('Hearst', 'NOUN'), (('castle', 'ADJ'), ('castle', 'NOUN'))],
#  [('San', 'NOUN'), (('Simeon', 'ADJ'), ('Simeon', 'NOUN'))],
#  [('.', '.'), (('Citizens', 'ADJ'), ('Citizens', 'NOUN'))],
#  [('in', 'ADP'), (('Peninsula', 'ADJ'), ('Peninsula', 'NOUN'))],
#  [('``', '.'), (('Lighthouse', 'ADJ'), ('Lighthouse', 'NOUN'))],
#  [('was', 'VERB'), (('painted', 'ADJ'), ('painted', 'VERB'))],
#  [('in', 'ADP'), (('oils', 'ADJ'), ('oils', 'NOUN'))],
#  [('the', 'DET'), (('playwright', 'ADJ'), ('playwright', 'NOUN'))],
#  [('in', 'ADP'), (('1901', 'ADJ'), ('1901', 'NUM'))],
#  [('$', '.'), (('6,500', 'ADJ'), ('6,500', 'NUM'))],
#  [('send', 'VERB'), (('continuously', 'ADJ'), ('continuously', 'ADV'))],
#  [('changing', 'VERB'), (('colored', 'ADJ'), ('colored', 'VERB'))],
#  [('colored', 'VERB'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('fiber-end', 'ADJ'), (('bunches', 'ADJ'), ('bunches', 'NOUN'))],
#  [('disclosed', 'VERB'), (('*-93', 'ADJ'), ('*-93', 'X'))],
#  [('the', 'DET'), (('YMCA', 'ADJ'), ('YMCA', 'NOUN'))],
#  [('the', 'DET'), (('YWCA', 'ADJ'), ('YWCA', 'NOUN'))],
#  [('or', 'CONJ'), (('Catholic', 'ADJ'), ('Catholic', 'NOUN'))],
#  [('Charities', 'NOUN'), (('USA', 'ADJ'), ('USA', 'NOUN'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-17', 'X'), (('participated', 'ADJ'), ('participated', 'VERB'))],
#  [("'", 'PRT'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('would', 'VERB'), (('end', 'NOUN'), ('end', 'VERB'))],
#  [('$', '.'), (('620', 'ADJ'), ('620', 'NUM'))],
#  [('covers', 'VERB'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-260', 'ADJ'), ('*T*-260', 'X'))],
#  [(',', '.'), (('30.6', 'ADJ'), ('30.6', 'NUM'))],
#  [('with', 'ADP'), (('27.4', 'ADJ'), ('27.4', 'NUM'))],
#  [('and', 'CONJ'), (('26.5', 'ADJ'), ('26.5', 'NUM'))],
#  [('.', '.'), (('Compromises', 'ADJ'), ('Compromises', 'NOUN'))],
#  [('That', 'DET'), (('divergence', 'ADJ'), ('divergence', 'NOUN'))],
#  [('last', 'ADJ'), (('count', 'ADJ'), ('count', 'NOUN'))],
#  [('things', 'NOUN'), (('straight', 'ADJ'), ('straight', 'ADV'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'ADJ'), ('triple', 'ADV'))],
#  [('is', 'VERB'), (('chiefly', 'ADJ'), ('chiefly', 'ADV'))],
#  [('*T*-2', 'X'), (('Ichiro', 'ADJ'), ('Ichiro', 'NOUN'))],
#  [('an', 'DET'), (('executive', 'ADJ'), ('executive', 'NOUN'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('possible', 'ADJ'), (('white', 'NOUN'), ('white', 'ADJ'))],
#  [('white', 'ADJ'), (('knight', 'ADJ'), ('knight', 'NOUN'))],
#  [('for', 'ADP'), (('Great', 'NOUN'), ('Great', 'ADJ'))],
#  [("n't", 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [('you', 'PRON'), (('photocopy', 'ADJ'), ('photocopy', 'VERB'))],
#  [('for', 'ADP'), (('CTB', 'ADJ'), ('CTB', 'NOUN'))],
#  [('division', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-106', 'ADJ'), ('*T*-106', 'X'))],
#  [('transaction', 'NOUN'), (('sound', 'NOUN'), ('sound', 'VERB'))],
#  [('debt', 'NOUN'), (('load', 'VERB'), ('load', 'NOUN'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('almost', 'ADV'), (('over', 'ADP'), ('over', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-100', 'ADJ'), ('*T*-100', 'X'))],
#  [('the', 'DET'), (('crib', 'ADJ'), ('crib', 'NOUN'))],
#  [('Japanese', 'ADJ'), (('contribution', 'ADJ'), ('contribution', 'NOUN'))],
#  [('*-1', 'X'), (('Left', 'ADJ'), ('Left', 'VERB'))],
#  [('and', 'CONJ'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('$', '.'), (('777', 'ADJ'), ('777', 'NUM'))],
#  [('somewhat', 'ADV'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('anticipated', 'VERB'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('to', 'PRT'), (('arrive', 'ADJ'), ('arrive', 'VERB'))],
#  [('prices', 'NOUN'), (('firmed', 'ADJ'), ('firmed', 'VERB'))],
#  [('firmed', 'VERB'), (('only', 'ADJ'), ('only', 'ADV'))],
#  [('then', 'ADV'), (('faltered', 'ADJ'), ('faltered', 'VERB'))],
#  [('vehicles', 'NOUN'), (('classed', 'ADJ'), ('classed', 'VERB'))],
#  [('carry', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('and', 'CONJ'), (('therefore', 'ADJ'), ('therefore', 'ADV'))],
#  [('quite', 'ADV'), (('content', 'NOUN'), ('content', 'ADJ'))],
#  [('advertising', 'NOUN'), (('standpoint', 'ADJ'), ('standpoint', 'NOUN'))],
#  [('folks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-153', 'ADJ'), ('*T*-153', 'X'))],
#  [('unwanted', 'ADJ'), (('suitors', 'ADJ'), ('suitors', 'NOUN'))],
#  [('the', 'DET'), (('start-up', 'ADJ'), ('start-up', 'NOUN'))],
#  [('the', 'DET'),
#   (('information-services', 'ADJ'), ('information-services', 'NOUN'))],
#  [('spent', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('--', '.'), (('including', 'VERB'), ('including', 'ADP'))],
#  [(',', '.'), (('Greece', 'ADJ'), ('Greece', 'NOUN'))],
#  [('for', 'ADP'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('Van', 'NOUN'), (('Alstyne', 'ADJ'), ('Alstyne', 'NOUN'))],
#  [('Alstyne', 'NOUN'), (('notes', 'NOUN'), ('notes', 'VERB'))],
#  [('bad', 'ADJ'), (('apple', 'ADJ'), ('apple', 'NOUN'))],
#  [('his', 'PRON'), (('apples', 'ADJ'), ('apples', 'NOUN'))],
#  [('of', 'ADP'), (('emigres', 'ADJ'), ('emigres', 'NOUN'))],
#  [('*-2', 'X'), (('Knowing', 'ADJ'), ('Knowing', 'VERB'))],
#  [('they', 'PRON'), (('eat', 'ADJ'), ('eat', 'VERB'))],
#  [('a', 'DET'), (('standing', 'NOUN'), ('standing', 'ADJ'))],
#  [('standing', 'ADJ'), (('ovation', 'ADJ'), ('ovation', 'NOUN'))],
#  [('J.', 'NOUN'), (('Danzig', 'ADJ'), ('Danzig', 'NOUN'))],
#  [('Hearst', 'NOUN'), (('Newspapers', 'ADJ'), ('Newspapers', 'NOUN'))],
#  [('stood', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('*-2', 'X'), (('putting', 'ADJ'), ('putting', 'VERB'))],
#  [('than', 'ADP'), (('730', 'ADJ'), ('730', 'NUM'))],
#  [('employees', 'NOUN'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('Not', 'ADV'), (('counting', 'ADJ'), ('counting', 'VERB'))],
#  [('*T*-1', 'X'), (('co-founded', 'ADJ'), ('co-founded', 'VERB'))],
#  [('annually', 'ADV'), (('total', 'ADJ'), ('total', 'VERB'))],
#  [('$', '.'), (('38.3', 'ADJ'), ('38.3', 'NUM'))],
#  [('unusual', 'ADJ'), (('write-downs', 'ADJ'), ('write-downs', 'NOUN'))],
#  [('$', '.'), (('4.9', 'ADJ'), ('4.9', 'NUM'))],
#  [('in', 'ADP'), (('Bermuda', 'ADJ'), ('Bermuda', 'NOUN'))],
#  [('buying', 'VERB'), (('back', 'ADV'), ('back', 'PRT'))],
#  [('Have', 'NOUN'), (('Wa', 'NOUN'), ('Wa', '.'))],
#  [(',', '.'), (('339', 'ADJ'), ('339', 'NUM'))],
#  [("''", '.'), (('Hammacher', 'ADJ'), ('Hammacher', 'NOUN'))],
#  [('Hammacher', 'NOUN'), (('Schlemmer', 'ADJ'), ('Schlemmer', 'NOUN'))],
#  [('fiber-optic', 'ADJ'), (('Christmas', 'ADJ'), ('Christmas', 'NOUN'))],
#  [('tree', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('string', 'ADJ'), ('string', 'VERB'))],
#  [('string', 'VERB'), (('lights', 'ADJ'), ('lights', 'NOUN'))],
#  [('by', 'ADP'), (('Blackstone', 'ADJ'), ('Blackstone', 'NOUN'))],
#  [('$', '.'), (('19.50', 'ADJ'), ('19.50', 'NUM'))],
#  [('.', '.'), (('Propaganda', 'ADJ'), ('Propaganda', 'NOUN'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('own', 'ADJ'), (('mind', 'VERB'), ('mind', 'NOUN'))],
#  [('in', 'ADP'), (('Heidelberg', 'ADJ'), ('Heidelberg', 'NOUN'))],
#  [('who', 'PRON'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('.', '.'), (('Billings', 'ADJ'), ('Billings', 'NOUN'))],
#  [('which', 'DET'), (('*T*-155', 'ADJ'), ('*T*-155', 'X'))],
#  [('been', 'VERB'), (('serviced', 'ADJ'), ('serviced', 'VERB'))],
#  [('&', 'CONJ'), (('Rubicam', 'ADJ'), ('Rubicam', 'NOUN'))],
#  [('will', 'VERB'), (('direct', 'ADJ'), ('direct', 'VERB'))],
#  [('reduce', 'VERB'), (('overhead', 'ADJ'), ('overhead', 'NOUN'))],
#  [('a', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('is', 'VERB'), (('achieved', 'ADJ'), ('achieved', 'VERB'))],
#  [('``', '.'), (('mirror', 'VERB'), ('mirror', 'NOUN'))],
#  [('fabled', 'ADJ'), (('virtues', 'ADJ'), ('virtues', 'NOUN'))],
#  [('$', '.'), (('81.8', 'ADJ'), ('81.8', 'NUM'))],
#  [('of', 'ADP'), (('7.20', 'ADJ'), ('7.20', 'NUM'))]]

# %% [markdown]
# ### Solve the problem of unknown words- Solution 1

# %%
# Modifying the vanilla veterbi. If the word in unknown then consider only the transition probability
def Viterbi_modified1(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            
            # if word in not in the training set then consider only the transition probability
            if word not in V:
                state_probability = transition_p    
            else:
                state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# tagging the test sentences using the 1st modification
start = time.time()
tagged_seq_modified1 = Viterbi_modified1(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
print(tagged_seq_modified1)
# Out:
# Time taken in seconds:  924.1084666252136
# [('Mr.', 'NOUN'), ('Trump', 'NOUN'), ('withdrew', 'NOUN'), ('a', 'DET'), ('$', '.'), ('120-a-share', 'NOUN'), ('*U*', 'X'), ('bid', 'VERB'), ('last', 'ADJ'), ('month', 'NOUN'), ('.', '.'), ('Japan', 'NOUN'), ("'s", 'PRT'), ('Finance', 'NOUN'), ('Ministry', 'NOUN'), ('had', 'VERB'), ('set', 'VERB'), ('up', 'ADV'), ('mechanisms', 'VERB'), ('0', 'X'), ('*-1', 'X'), ('to', 'PRT'), ('limit', 'NOUN'), ('how', 'ADV'), ('far', 'ADV'), ('futures', 'NOUN'), ('prices', 'NOUN'), ('could', 'VERB'), ('fall', 'VERB'), ('*T*-2', 'X'), ('in', 'ADP'), ('a', 'DET'), ('single', 'ADJ'), ('session', 'NOUN'), ('and', 'CONJ'), ('*-1', 'X'), ('to', 'PRT'), ('give', 'VERB'), ('market', 'NOUN'), ('operators', 'NOUN'), ('the', 'DET'), ('authority', 'NOUN'), ('*', 'X'), ('to', 'PRT'), ('suspend', 'VERB'), ('trading', 'NOUN'), ('in', 'ADP'), ('futures', 'NOUN'), ('at', 'ADP'), ('any', 'DET'), ('time', 'NOUN'), ('.', '.'), ('I', 'PRON'), ('have', 'VERB'), ('a', 'DET'), ('right', 'NOUN'), ('*-1', 'X'), ('to', 'PRT'), ('print', 'VERB'), ('those', 'DET'), ('scripts', 'NOUN'), ('if', 'ADP'), ('I', 'PRON'), ('go', 'VERB'), ('there', 'DET'), ('and', 'CONJ'), ('laboriously', 'NOUN'), ('--', '.'), ('but', 'CONJ'), ('no', 'DET'), ('longer', 'ADJ'), ('surreptitiously', 'NOUN'), ('--', '.'), ('copy', 'VERB'), ('them', 'PRON'), ('out', 'PRT'), ('in', 'ADP'), ('long', 'ADJ'), ('hand', 'NOUN'), ('.', '.'), ('*', 'X'), ('Take', 'VERB'), ('Lake', 'NOUN'), ('Vineyard', 'NOUN'), ('Cabernet', 'NOUN'), ('from', 'ADP'), ('Diamond', 'NOUN'), ('Creek', 'NOUN'), ('.', '.'), ('And', 'CONJ'), ('unlike', 'ADJ'), ('some', 'DET'), ('trays', 'NOUN'), (',', '.'), ('there', 'DET'), ("'s", 'VERB'), ('no', 'DET'), ('place', 'NOUN'), ('for', 'ADP'), ('food', 'NOUN'), ('.', '.'), ('Standard', 'NOUN'), ('&', 'CONJ'), ('Poor', 'NOUN'), ("'s", 'PRT'), ('Corp.', 'NOUN'), ('says', 'VERB'), ('0', 'X'), ('First', 'NOUN'), ('Boston', 'NOUN'), (',', '.'), ('Shearson', 'NOUN'), ('and', 'CONJ'), ('Drexel', 'NOUN'), ('Burnham', 'NOUN'), ('Lambert', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('in', 'ADP'), ('particular', 'ADJ'), (',', '.'), ('are', 'VERB'), ('likely', 'ADJ'), ('*-1', 'X'), ('to', 'PRT'), ('have', 'VERB'), ('difficulty', 'X'), ('*-2', 'X'), ('shoring', 'VERB'), ('up', 'ADV'), ('their', 'PRON'), ('credit', 'NOUN'), ('standing', 'NOUN'), ('in', 'ADP'), ('months', 'NOUN'), ('ahead', 'ADV'), ('.', '.'), ('Also', 'ADV'), (',', '.'), ('Big', 'NOUN'), ('Board', 'NOUN'), ('Chairman', 'NOUN'), ('Phelan', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('he', 'PRON'), ('would', 'VERB'), ('support', 'VERB'), ('SEC', 'NOUN'), ('halts', 'NOUN'), ('of', 'ADP'), ('program', 'NOUN'), ('trading', 'NOUN'), ('during', 'ADP'), ('market', 'NOUN'), ('crises', 'NOUN'), ('but', 'CONJ'), ('not', 'ADV'), ('any', 'DET'), ('revival', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('``', '.'), ('collar', 'NOUN'), ("''", '.'), ('on', 'ADP'), ('trading', 'NOUN'), ('.', '.'), ('Columbia', 'NOUN'), ('Savings', 'NOUN'), ('&', 'CONJ'), ('Loan', 'NOUN'), ('-LRB-', '.'), ('NYSE', 'NOUN'), (';', '.'), ('Symbol', 'NOUN'), (':', '.'), ('CSV', 'NOUN'), ('-RRB-', '.'), ('I', 'PRON'), ('say', 'VERB'), ('``', '.'), ('*', 'X'), ('contained', 'VERB'), ('dialogue', 'NOUN'), ("''", '.'), ('because', 'ADP'), ('``', '.'), ('Sidewalk', 'NOUN'), ('Stories', 'NOUN'), ("''", '.'), ('is', 'VERB'), ("n't", 'ADV'), ('really', 'ADV'), ('silent', 'ADJ'), ('at', 'ADP'), ('all', 'DET'), ('.', '.'), ('In', 'ADP'), ('his', 'PRON'), ('return', 'VERB'), ('toast', 'NOUN'), ('to', 'PRT'), ('Mr.', 'NOUN'), ('Nixon', 'NOUN'), (',', '.'), ('Mr.', 'NOUN'), ('Yang', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('the', 'DET'), ('relationship', 'NOUN'), ('had', 'VERB'), ('reached', 'VERB'), ('a', 'DET'), ('``', '.'), ('stalemate', 'NOUN'), ('.', '.'), ("''", '.'), ('Municipal', 'NOUN'), ('bonds', 'NOUN'), ('were', 'VERB'), ('mostly', 'ADV'), ('unchanged', 'ADJ'), ('to', 'PRT'), ('up', 'ADV'), ('1\\/8', 'NUM'), ('point', 'NOUN'), ('in', 'ADP'), ('light', 'ADJ'), (',', '.'), ('cautious', 'AD ...

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
# accuracy
check_modified1 = [i for i, j in zip(tagged_seq_modified1, test_run_base) if i == j] 
accuracy_modified1 = len(check_modified1)/len(tagged_seq_modified1)
accuracy_modified1
# Out:
# 0.9405601450735442

# %%
# Finiding the incorrectly tagged cases
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq_modified1, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('Trump', 'NOUN'), (('withdrew', 'NOUN'), ('withdrew', 'VERB'))],
#  [('$', '.'), (('120-a-share', 'NOUN'), ('120-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('set', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('up', 'PRT'), (('mechanisms', 'VERB'), ('mechanisms', 'NOUN'))],
#  [('to', 'PRT'), (('limit', 'NOUN'), ('limit', 'VERB'))],
#  [('how', 'ADV'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('go', 'VERB'), (('there', 'DET'), ('there', 'ADV'))],
#  [('and', 'CONJ'), (('laboriously', 'NOUN'), ('laboriously', 'ADV'))],
#  [('but', 'CONJ'), (('no', 'DET'), ('no', 'ADV'))],
#  [('longer', 'ADJ'),
#   (('surreptitiously', 'NOUN'), ('surreptitiously', 'ADV'))],
#  [('And', 'CONJ'), (('unlike', 'ADJ'), ('unlike', 'ADP'))],
#  [('have', 'VERB'), (('difficulty', 'X'), ('difficulty', 'NOUN'))],
#  [('shoring', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('his', 'PRON'), (('return', 'VERB'), ('return', 'NOUN'))],
#  [("''", '.'), (('Municipal', 'NOUN'), ('Municipal', 'ADJ'))],
#  [('took', 'VERB'), (('further', 'ADV'), ('further', 'ADJ'))],
#  [('further', 'ADJ'), (('steps', 'VERB'), ('steps', 'NOUN'))],
#  [('thing', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('market', 'NOUN'), (('right', 'NOUN'), ('right', 'ADV'))],
#  [('right', 'ADV'), (('open', 'VERB'), ('open', 'ADJ'))],
#  [('is', 'VERB'), (('merchandising', 'X'), ('merchandising', 'NOUN'))],
#  [('in', 'ADP'), (('idiomatic', 'DET'), ('idiomatic', 'ADJ'))],
#  [('bought', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('may', 'VERB'), (('challenge', 'NOUN'), ('challenge', 'VERB'))],
#  [('included', 'VERB'), (('checking', 'NOUN'), ('checking', 'VERB'))],
#  [(',', '.'), (('safe', 'NOUN'), ('safe', 'ADJ'))],
#  [('--', '.'), (('plus', 'CONJ'), ('plus', 'ADV'))],
#  [('an', 'DET'), (('inspirational', 'NOUN'), ('inspirational', 'ADJ'))],
#  [('it', 'PRON'), (('all', 'DET'), ('all', 'ADV'))],
#  [('*T*-1', 'X'), (('Laura', 'VERB'), ('Laura', 'NOUN'))],
#  [('Laura', 'NOUN'), (('Dobson', 'X'), ('Dobson', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-90', 'VERB'), ('*T*-90', 'X'))],
#  [('the', 'DET'), (('teacher-cadet', 'NOUN'), ('teacher-cadet', 'ADJ'))],
#  [('an', 'DET'), (('individual', 'ADJ'), ('individual', 'NOUN'))],
#  [('may', 'VERB'), (('care', 'NOUN'), ('care', 'VERB'))],
#  [('about', 'ADP'), (('Senior', 'DET'), ('Senior', 'NOUN'))],
#  [('a', 'DET'), (('75-year-old', 'NOUN'), ('75-year-old', 'NUM'))],
#  [('may', 'VERB'), (('care', 'NOUN'), ('care', 'VERB'))],
#  [('very', 'ADV'), (('complicated', 'ADJ'), ('complicated', 'VERB'))],
#  [('been', 'VERB'), (('firmly', 'X'), ('firmly', 'ADV'))],
#  [('an', 'DET'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('this', 'DET'), (('engaging', 'VERB'), ('engaging', 'ADJ'))],
#  [('the', 'DET'), (('buttoned-down', 'NOUN'), ('buttoned-down', 'ADJ'))],
#  [('contemporary', 'ADJ'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('which', 'DET'), (('*T*-112', 'NOUN'), ('*T*-112', 'X'))],
#  [('the', 'DET'), (('acting', 'NOUN'), ('acting', 'ADJ'))],
#  [('industrial', 'ADJ'), (('average', 'ADJ'), ('average', 'NOUN'))],
#  [(':', '.'), (('Can', 'NOUN'), ('Can', 'VERB'))],
#  [('like', 'ADP'), (('hard-charging', 'DET'), ('hard-charging', 'ADJ'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('a', 'DET'), (('first-rate', 'NOUN'), ('first-rate', 'ADJ'))],
#  [('of', 'ADP'), (('excise', 'VERB'), ('excise', 'ADJ'))],
#  [('presented', 'VERB'), (('claims', 'VERB'), ('claims', 'NOUN'))],
#  [('chief', 'NOUN'), (('operating', 'NOUN'), ('operating', 'VERB'))],
#  [('of', 'ADP'), (('Toys', 'DET'), ('Toys', 'NOUN'))],
#  [('of', 'ADP'), (('Signet', 'DET'), ('Signet', 'NOUN'))],
#  [('was', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('opening', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('wines', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-168', 'DET'), ('*T*-168', 'X'))],
#  [('*T*-168', 'X'), (('appeal', 'NOUN'), ('appeal', 'VERB'))],
#  [(',', '.'), (('retraced', 'NOUN'), ('retraced', 'VERB'))],
#  [('to', 'PRT'), (('end', 'NOUN'), ('end', 'VERB'))],
#  [('a', 'DET'), (('83.4', 'NOUN'), ('83.4', 'NUM'))],
#  [('this', 'DET'), (('energy-services', 'NOUN'), ('energy-services', 'ADJ'))],
#  [('before', 'ADP'), (('that', 'DET'), ('that', 'ADP'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('of', 'ADP'), (('Landor', 'DET'), ('Landor', 'NOUN'))],
#  [('.', '.'), (('Yet', 'CONJ'), ('Yet', 'ADV'))],
#  [("'s", 'PRT'), (('hypocrisy', 'VERB'), ('hypocrisy', 'NOUN'))],
#  [('two', 'NUM'), (('round-trip', 'NOUN'), ('round-trip', 'ADJ'))],
#  [('on', 'ADP'), (('Trans', 'DET'), ('Trans', 'NOUN'))],
#  [('plus', 'CONJ'), (('accrued', 'NOUN'), ('accrued', 'VERB'))],
#  [('circuit-breaker', 'NOUN'),
#   (('aggravated', 'NOUN'), ('aggravated', 'VERB'))],
#  [('additional', 'ADJ'), (('selling', 'NOUN'), ('selling', 'VERB'))],
#  [('produce', 'VERB'), (('consistent', 'X'), ('consistent', 'ADJ'))],
#  [('has', 'VERB'), (('wedded', 'X'), ('wedded', 'VERB'))],
#  [('at', 'ADP'), (('60.36', 'DET'), ('60.36', 'NUM'))],
#  [('an', 'DET'), (('early-retirement', 'NOUN'), ('early-retirement', 'ADJ'))],
#  [('companies', 'NOUN'), (('bankroll', 'NOUN'), ('bankroll', 'VERB'))],
#  [('with', 'ADP'), (('promising', 'DET'), ('promising', 'ADJ'))],
#  [('.', '.'), (('Performing', 'NOUN'), ('Performing', 'VERB'))],
#  [('RMS', 'NOUN'), (('distributes', 'NOUN'), ('distributes', 'VERB'))],
#  [('and', 'CONJ'), (('produces', 'NOUN'), ('produces', 'VERB'))],
#  [('power', 'NOUN'), (('supplies', 'VERB'), ('supplies', 'NOUN'))],
#  [('which', 'DET'), (('*T*-174', 'NOUN'), ('*T*-174', 'X'))],
#  [('operates', 'VERB'), (('hotels', 'X'), ('hotels', 'NOUN'))],
#  [('rights', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-175', 'DET'), ('*T*-175', 'X'))],
#  [('of', 'ADP'), (('Child', 'DET'), ('Child', 'NOUN'))],
#  [(',', '.'), (('restored', 'NOUN'), ('restored', 'VERB'))],
#  [('been', 'VERB'), (('limping', 'X'), ('limping', 'VERB'))],
#  [('on', 'ADP'), (('limited', 'ADJ'), ('limited', 'VERB'))],
#  [('its', 'PRON'), (('accomplishments', 'VERB'), ('accomplishments', 'NOUN'))],
#  [('were', 'VERB'), (('notable', 'X'), ('notable', 'ADJ'))],
#  [('.', '.'), (('9.82', 'NOUN'), ('9.82', 'NUM'))],
#  [('rate', 'NOUN'), (('capped', 'VERB'), ('capped', 'ADJ'))],
#  [('.', '.'), (('Financially', 'NOUN'), ('Financially', 'ADV'))],
#  [('its', 'PRON'), (('moments', 'VERB'), ('moments', 'NOUN'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('be', 'VERB'), (('scared', 'ADJ'), ('scared', 'VERB'))],
#  [('*-83', 'X'), (('away', 'PRT'), ('away', 'ADV'))],
#  [('Poore', 'NOUN'), (('replies', 'NOUN'), ('replies', 'VERB'))],
#  [('a', 'DET'), (('gigantic', 'NOUN'), ('gigantic', 'ADJ'))],
#  [('the', 'DET'), (('top-yielding', 'NOUN'), ('top-yielding', 'ADJ'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('of', 'ADP'), (('9.37', 'DET'), ('9.37', 'NUM'))],
#  [('from', 'ADP'), (('9.45', 'DET'), ('9.45', 'NUM'))],
#  [('week', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('of', 'ADP'), (('rusted', 'DET'), ('rusted', 'VERB'))],
#  [('drums', 'NOUN'), (('swim', 'NOUN'), ('swim', 'VERB'))],
#  [('voice', 'NOUN'), (('purrs', 'NOUN'), ('purrs', 'VERB'))],
#  [('her', 'PRON'), (('motives', 'VERB'), ('motives', 'NOUN'))],
#  [('were', 'VERB'), (('correct', 'VERB'), ('correct', 'ADJ'))],
#  [('The', 'DET'), (('multilevel', 'NOUN'), ('multilevel', 'ADJ'))],
#  [('by', 'ADP'), (('Thrall', 'DET'), ('Thrall', 'NOUN'))],
#  [('held', 'VERB'), (('Duchossois', 'X'), ('Duchossois', 'NOUN'))],
#  [('By', 'ADP'), (('1997', 'DET'), ('1997', 'NUM'))],
#  [('remaining', 'VERB'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('of', 'ADP'), (('cancer-causing', 'DET'), ('cancer-causing', 'ADJ'))],
#  [('be', 'VERB'), (('outlawed', 'X'), ('outlawed', 'VERB'))],
#  [('or', 'CONJ'), (('retaliating', 'NOUN'), ('retaliating', 'VERB'))],
#  [('when', 'ADV'), (('trading', 'VERB'), ('trading', 'NOUN'))],
#  [('trading', 'NOUN'), (('resumes', 'X'), ('resumes', 'VERB'))],
#  [('futures', 'NOUN'), (('fall', 'NOUN'), ('fall', 'VERB'))],
#  [("'s", 'PRT'), (('close', 'VERB'), ('close', 'NOUN'))],
#  [('tight', 'ADJ'), (('facial', 'NOUN'), ('facial', 'ADJ'))],
#  [('facial', 'ADJ'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('another', 'DET'), (('drag-down', 'NOUN'), ('drag-down', 'ADJ'))],
#  [('team', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('too', 'ADV'), (('low', 'ADJ'), ('low', 'ADV'))],
#  [('most', 'ADJ'), (('practical', 'NOUN'), ('practical', 'ADJ'))],
#  [('practical', 'ADJ'), (('uses', 'VERB'), ('uses', 'NOUN'))],
#  [('Younkers', 'NOUN'), (('rang', 'NOUN'), ('rang', 'VERB'))],
#  [('$', '.'), (('313', 'NOUN'), ('313', 'NUM'))],
#  [('level', 'NOUN'), (('playing', 'VERB'), ('playing', 'NOUN'))],
#  [('Hahn', 'NOUN'), (('attributes', 'NOUN'), ('attributes', 'VERB'))],
#  [('the', 'DET'), (('absolute', 'NOUN'), ('absolute', 'ADJ'))],
#  [('the', 'DET'), (('scholarly', 'NOUN'), ('scholarly', 'ADJ'))],
#  [('prime', 'ADJ'), (('borrowing', 'NOUN'), ('borrowing', 'VERB'))],
#  [('--', '.'), (('and', 'CONJ'), ('and', 'ADJ'))],
#  [('having', 'VERB'), (('borrowed', 'X'), ('borrowed', 'VERB'))],
#  [('$', '.'), (('3.4', 'NOUN'), ('3.4', 'NUM'))],
#  [(',', '.'), (('Bermuda-based', 'NOUN'), ('Bermuda-based', 'ADJ'))],
#  [('Bermuda-based', 'ADJ'), (('shipping', 'VERB'), ('shipping', 'NOUN'))],
#  [('0', 'X'), (('most', 'ADV'), ('most', 'ADJ'))],
#  [('and', 'CONJ'), (('257', 'NOUN'), ('257', 'NUM'))],
#  [('shut', 'VERB'), (('down', 'ADV'), ('down', 'PRT'))],
#  [('the', 'DET'), (('equivalent', 'ADJ'), ('equivalent', 'NOUN'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('a', 'DET'), (('150-point', 'NOUN'), ('150-point', 'ADJ'))],
#  [('a', 'DET'), (('vast', 'NOUN'), ('vast', 'ADJ'))],
#  [('is', 'VERB'), (('payable', 'X'), ('payable', 'ADJ'))],
#  [('payable', 'ADJ'), (('Jan.', 'VERB'), ('Jan.', 'NOUN'))],
#  [('Gulf', 'NOUN'), (('spurns', 'NOUN'), ('spurns', 'VERB'))],
#  [('the', 'DET'), (('morale-damaging', 'NOUN'), ('morale-damaging', 'ADJ'))],
#  [('morale-damaging', 'ADJ'), (('public', 'NOUN'), ('public', 'ADJ'))],
#  [('*U*', 'X'), (('gain', 'VERB'), ('gain', 'NOUN'))],
#  [('would', 'VERB'), (('like', 'ADP'), ('like', 'VERB'))],
#  [('a', 'DET'), (('packed', 'NOUN'), ('packed', 'ADJ'))],
#  [('On', 'ADP'), (('weekends', 'DET'), ('weekends', 'NOUN'))],
#  [('prepare', 'VERB'), (('study', 'VERB'), ('study', 'NOUN'))],
#  [('study', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('*', 'X'), (('Possibly', 'VERB'), ('Possibly', 'ADV'))],
#  [('offsetting', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('has', 'VERB'), (('unrealized', 'X'), ('unrealized', 'ADJ'))],
#  [('be', 'VERB'), (('gradually', 'X'), ('gradually', 'ADV'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('consumer', 'NOUN'), (('banking', 'NOUN'), ('banking', 'VERB'))],
#  [(':', '.'), (('day-care', 'NOUN'), ('day-care', 'ADJ'))],
#  [('day-care', 'ADJ'), (('centers', 'VERB'), ('centers', 'NOUN'))],
#  [('centers', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('legislation', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('is', 'VERB'), (('unlikely', 'X'), ('unlikely', 'ADJ'))],
#  [('from', 'ADP'), (('Tokio', 'DET'), ('Tokio', 'NOUN'))],
#  [('on', 'ADP'), (('preventative', 'DET'), ('preventative', 'ADJ'))],
#  [('the', 'DET'), (('junk-bond', 'NOUN'), ('junk-bond', 'ADJ'))],
#  [('they', 'PRON'), (('own', 'ADJ'), ('own', 'VERB'))],
#  [('would', 'VERB'), (('assess', 'X'), ('assess', 'VERB'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('to', 'PRT'), (('500,004', 'VERB'), ('500,004', 'NUM'))],
#  [('their', 'PRON'), (('wives', 'VERB'), ('wives', 'NOUN'))],
#  [('wives', 'NOUN'), (('raced', 'X'), ('raced', 'VERB'))],
#  [('*-1', 'X'), (('unimpeded', 'VERB'), ('unimpeded', 'ADJ'))],
#  [('by', 'ADP'), (('traffic', 'DET'), ('traffic', 'NOUN'))],
#  [('Its', 'PRON'), (('fanciful', 'VERB'), ('fanciful', 'ADJ'))],
#  [('in', 'ADP'), (('Peninsula', 'DET'), ('Peninsula', 'NOUN'))],
#  [("'s", 'PRT'), (('floral', 'VERB'), ('floral', 'ADJ'))],
#  [('was', 'VERB'), (('painted', 'X'), ('painted', 'VERB'))],
#  [('in', 'ADP'), (('oils', 'DET'), ('oils', 'NOUN'))],
#  [('in', 'ADP'), (('1901', 'DET'), ('1901', 'NUM'))],
#  [('$', '.'), (('6,500', 'NOUN'), ('6,500', 'NUM'))],
#  [('send', 'VERB'), (('continuously', 'X'), ('continuously', 'ADV'))],
#  [('changing', 'VERB'), (('colored', 'X'), ('colored', 'VERB'))],
#  [('colored', 'VERB'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('of', 'ADP'), (('fiber-end', 'DET'), ('fiber-end', 'ADJ'))],
#  [('its', 'PRON'), (('longstanding', 'VERB'), ('longstanding', 'ADJ'))],
#  [('organizations', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("'", 'PRT'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('the', 'DET'), (('asset-sale', 'NOUN'), ('asset-sale', 'ADJ'))],
#  [('would', 'VERB'), (('end', 'NOUN'), ('end', 'VERB'))],
#  [('$', '.'), (('620', 'NOUN'), ('620', 'NUM'))],
#  [('covers', 'VERB'), (('only', 'ADV'), ('only', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-260', 'VERB'), ('*T*-260', 'X'))],
#  [(',', '.'), (('30.6', 'NOUN'), ('30.6', 'NUM'))],
#  [('with', 'ADP'), (('27.4', 'DET'), ('27.4', 'NUM'))],
#  [('and', 'CONJ'), (('26.5', 'NOUN'), ('26.5', 'NUM'))],
#  [('things', 'NOUN'), (('straight', 'ADJ'), ('straight', 'ADV'))],
#  [('.', '.'), (('No', 'DET'), ('No', 'ADV'))],
#  [(',', '.'), (('triple', 'NOUN'), ('triple', 'ADV'))],
#  [('a', 'DET'), (('Washington-based', 'NOUN'), ('Washington-based', 'ADJ'))],
#  [('is', 'VERB'), (('chiefly', 'X'), ('chiefly', 'ADV'))],
#  [('*T*-2', 'X'), (('Ichiro', 'VERB'), ('Ichiro', 'NOUN'))],
#  [('an', 'DET'), (('executive', 'ADJ'), ('executive', 'NOUN'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('possible', 'ADJ'), (('white', 'NOUN'), ('white', 'ADJ'))],
#  [('an', 'DET'), (('undisclosed', 'NOUN'), ('undisclosed', 'ADJ'))],
#  [('for', 'ADP'), (('Great', 'NOUN'), ('Great', 'ADJ'))],
#  [("n't", 'ADV'), (('there', 'DET'), ('there', 'ADV'))],
#  [('for', 'ADP'), (('CTB', 'DET'), ('CTB', 'NOUN'))],
#  [('division', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-106', 'DET'), ('*T*-106', 'X'))],
#  [('transaction', 'NOUN'), (('sound', 'NOUN'), ('sound', 'VERB'))],
#  [('debt', 'NOUN'), (('load', 'VERB'), ('load', 'NOUN'))],
#  [('the', 'DET'), (('past', 'ADJ'), ('past', 'NOUN'))],
#  [('almost', 'ADV'), (('over', 'ADP'), ('over', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-100', 'VERB'), ('*T*-100', 'X'))],
#  [('the', 'DET'), (('crib', 'ADJ'), ('crib', 'NOUN'))],
#  [('and', 'CONJ'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('$', '.'), (('777', 'NOUN'), ('777', 'NUM'))],
#  [('somewhat', 'ADV'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('anticipated', 'VERB'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('prices', 'NOUN'), (('firmed', 'NOUN'), ('firmed', 'VERB'))],
#  [('vehicles', 'NOUN'), (('classed', 'NOUN'), ('classed', 'VERB'))],
#  [('carry', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('and', 'CONJ'), (('therefore', 'NOUN'), ('therefore', 'ADV'))],
#  [('quite', 'ADV'), (('content', 'NOUN'), ('content', 'ADJ'))],
#  [('folks', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-153', 'DET'), ('*T*-153', 'X'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [('the', 'DET'), (('start-up', 'ADJ'), ('start-up', 'NOUN'))],
#  [('a', 'DET'), (('27-year', 'NOUN'), ('27-year', 'ADJ'))],
#  [('a', 'DET'), (('tall', 'NOUN'), ('tall', 'ADJ'))],
#  [('spent', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [("'s", 'PRT'), (('premier', 'VERB'), ('premier', 'ADJ'))],
#  [('--', '.'), (('including', 'VERB'), ('including', 'ADP'))],
#  [('pose', 'VERB'), (('less-serious', 'X'), ('less-serious', 'ADJ'))],
#  [('for', 'ADP'), (('American', 'NOUN'), ('American', 'ADJ'))],
#  [('Alstyne', 'NOUN'), (('notes', 'NOUN'), ('notes', 'VERB'))],
#  [('his', 'PRON'), (('apples', 'VERB'), ('apples', 'NOUN'))],
#  [('on', 'ADP'), (('cross-border', 'DET'), ('cross-border', 'ADJ'))],
#  [('of', 'ADP'), (('emigres', 'DET'), ('emigres', 'NOUN'))],
#  [('a', 'DET'), (('tasty', 'NOUN'), ('tasty', 'ADJ'))],
#  [('a', 'DET'), (('standing', 'NOUN'), ('standing', 'ADJ'))],
#  [('stood', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('putting', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('than', 'ADP'), (('730', 'DET'), ('730', 'NUM'))],
#  [('employees', 'NOUN'), (('out', 'PRT'), ('out', 'ADP'))],
#  [(',', '.'), (('Mo.-based', 'NOUN'), ('Mo.-based', 'ADJ'))],
#  [('annually', 'ADV'), (('total', 'ADJ'), ('total', 'VERB'))],
#  [('$', '.'), (('38.3', 'NOUN'), ('38.3', 'NUM'))],
#  [('$', '.'), (('4.9', 'NOUN'), ('4.9', 'NUM'))],
#  [('in', 'ADP'), (('Bermuda', 'DET'), ('Bermuda', 'NOUN'))],
#  [('buying', 'VERB'), (('back', 'ADV'), ('back', 'PRT'))],
#  [('Have', 'NOUN'), (('Wa', 'NOUN'), ('Wa', '.'))],
#  [(',', '.'), (('339', 'NOUN'), ('339', 'NUM'))],
#  [('the', 'DET'), (('Nipponese', 'NOUN'), ('Nipponese', 'ADJ'))],
#  [('a', 'DET'), (('fiber-optic', 'NOUN'), ('fiber-optic', 'ADJ'))],
#  [('tree', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('string', 'VERB'), (('lights', 'X'), ('lights', 'NOUN'))],
#  [('by', 'ADP'), (('Blackstone', 'DET'), ('Blackstone', 'NOUN'))],
#  [('$', '.'), (('19.50', 'NOUN'), ('19.50', 'NUM'))],
#  [('make', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('own', 'ADJ'), (('mind', 'VERB'), ('mind', 'NOUN'))],
#  [('a', 'DET'), (('wheel-loader', 'NOUN'), ('wheel-loader', 'ADJ'))],
#  [('in', 'ADP'), (('Heidelberg', 'DET'), ('Heidelberg', 'NOUN'))],
#  [('the', 'DET'), (('three-lawyer', 'NOUN'), ('three-lawyer', 'ADJ'))],
#  [('the', 'DET'), (('520-lawyer', 'NOUN'), ('520-lawyer', 'ADJ'))],
#  [('who', 'PRON'), (('earlier', 'ADJ'), ('earlier', 'ADV'))],
#  [('which', 'DET'), (('*T*-155', 'NOUN'), ('*T*-155', 'X'))],
#  [('been', 'VERB'), (('serviced', 'X'), ('serviced', 'VERB'))],
#  [('will', 'VERB'), (('direct', 'ADJ'), ('direct', 'VERB'))],
#  [('reduce', 'VERB'), (('overhead', 'ADJ'), ('overhead', 'NOUN'))],
#  [('a', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('is', 'VERB'), (('achieved', 'X'), ('achieved', 'VERB'))],
#  [(',', '.'), (('Nipponese', 'NOUN'), ('Nipponese', 'ADJ'))],
#  [('``', '.'), (('mirror', 'VERB'), ('mirror', 'NOUN'))],
#  [("'s", 'PRT'), (('fabled', 'VERB'), ('fabled', 'ADJ'))],
#  [('fabled', 'ADJ'), (('virtues', 'X'), ('virtues', 'NOUN'))],
#  [('$', '.'), (('81.8', 'NOUN'), ('81.8', 'NUM'))],
#  [('of', 'ADP'), (('7.20', 'DET'), ('7.20', 'NUM'))]]

# %% [markdown]
# ### Solve the problem of unknown words - Solution 2

# %%
# importing PorterStemmer
from nltk.stem.porter import PorterStemmer

# %%
# Creating PorterStemmer object
stemmer = PorterStemmer()

# %%
# Creating a dictionary of stemmized words with the original POS tags
stemmized_x = {}
for item in train_tagged_words:
    stemmized_x[stemmer.stem(item[0])] = item[1]

# %%
# method to return pos tags based on different rules
def custom_pos_tagger(word):
    stemmed_word = stemmer.stem(word)
    # checking if the input word from the test data is present on the stemmized_x dictinary
    if stemmed_word in stemmized_x:
        return stemmized_x[stemmed_word]
    # checking if the input word from the test data is present in the lower_train dictionary
    elif word.lower() in lower_train:
        return lower_train[word.lower()]
    else:
        return morphological_rule_based(word)

# %%
# Creating a dictinory of the lower cases of the words from train set with their POS tags
lower_train = {}
for item in train_tagged_words:
    lower_train[item[0].lower()] = item[1]

# %%
# Defining a method for morphological rule based POS tagging
def morphological_rule_based(word):
    suffix_1= ["ing", "ed", "es"]
    if word.istitle():
        return "NOUN"
    elif word.endswith("ing") or word.endswith("ed"):
        return "VERB"
    elif word.lower() in ['a', 'an', 'the', 'A', 'An', 'The']:
        return "DET"
    else:
        return None

# %%
# If emission probability is zero we consider only the trasition probaility
def Viterbi_modified2(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        
        if word not in V:
            state_max = custom_pos_tagger(word)
            # checking if our custom pos tagger worked or not. If it didnt work it will return 'None'
            if state_max is None:
                p = []
                for tag in T:
                    if key == 0:
                        transition_p = tags_df.loc['.', tag]
                    else:
                        transition_p = tags_df.loc[state[-1], tag]
                    
                    state_probability = transition_p    
                    p.append(state_probability)
                
                pmax = max(p)
                # getting state for which probability is maximum
                state_max = T[p.index(pmax)] 
            
        else:
            p = [] 
            for tag in T:
                if key == 0:
                    transition_p = tags_df.loc['.', tag]
                else:
                    transition_p = tags_df.loc[state[-1], tag]

                # compute emission and state probabilities
                emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
                state_probability = emission_p * transition_p    
                p.append(state_probability)

            pmax = max(p)
            # getting state for which probability is maximum
            state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
# tagging the test sentences using 2nd modification
start = time.time()
tagged_seq_modified2 = Viterbi_modified2(test_tagged_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
print(tagged_seq_modified2)
# Out:
# Time taken in seconds:  819.0802927017212
# [('Mr.', 'NOUN'), ('Trump', 'NOUN'), ('withdrew', 'NOUN'), ('a', 'DET'), ('$', '.'), ('120-a-share', 'NOUN'), ('*U*', 'X'), ('bid', 'VERB'), ('last', 'ADJ'), ('month', 'NOUN'), ('.', '.'), ('Japan', 'NOUN'), ("'s", 'PRT'), ('Finance', 'NOUN'), ('Ministry', 'NOUN'), ('had', 'VERB'), ('set', 'VERB'), ('up', 'ADV'), ('mechanisms', 'NOUN'), ('0', 'X'), ('*-1', 'X'), ('to', 'PRT'), ('limit', 'NOUN'), ('how', 'ADV'), ('far', 'ADV'), ('futures', 'NOUN'), ('prices', 'NOUN'), ('could', 'VERB'), ('fall', 'VERB'), ('*T*-2', 'X'), ('in', 'ADP'), ('a', 'DET'), ('single', 'ADJ'), ('session', 'NOUN'), ('and', 'CONJ'), ('*-1', 'X'), ('to', 'PRT'), ('give', 'VERB'), ('market', 'NOUN'), ('operators', 'NOUN'), ('the', 'DET'), ('authority', 'NOUN'), ('*', 'X'), ('to', 'PRT'), ('suspend', 'VERB'), ('trading', 'NOUN'), ('in', 'ADP'), ('futures', 'NOUN'), ('at', 'ADP'), ('any', 'DET'), ('time', 'NOUN'), ('.', '.'), ('I', 'PRON'), ('have', 'VERB'), ('a', 'DET'), ('right', 'NOUN'), ('*-1', 'X'), ('to', 'PRT'), ('print', 'VERB'), ('those', 'DET'), ('scripts', 'NOUN'), ('if', 'ADP'), ('I', 'PRON'), ('go', 'VERB'), ('there', 'DET'), ('and', 'CONJ'), ('laboriously', 'NOUN'), ('--', '.'), ('but', 'CONJ'), ('no', 'DET'), ('longer', 'ADJ'), ('surreptitiously', 'NOUN'), ('--', '.'), ('copy', 'VERB'), ('them', 'PRON'), ('out', 'PRT'), ('in', 'ADP'), ('long', 'ADJ'), ('hand', 'NOUN'), ('.', '.'), ('*', 'X'), ('Take', 'VERB'), ('Lake', 'NOUN'), ('Vineyard', 'NOUN'), ('Cabernet', 'NOUN'), ('from', 'ADP'), ('Diamond', 'NOUN'), ('Creek', 'NOUN'), ('.', '.'), ('And', 'CONJ'), ('unlike', 'ADJ'), ('some', 'DET'), ('trays', 'NOUN'), (',', '.'), ('there', 'DET'), ("'s", 'VERB'), ('no', 'DET'), ('place', 'NOUN'), ('for', 'ADP'), ('food', 'NOUN'), ('.', '.'), ('Standard', 'NOUN'), ('&', 'CONJ'), ('Poor', 'NOUN'), ("'s", 'PRT'), ('Corp.', 'NOUN'), ('says', 'VERB'), ('0', 'X'), ('First', 'NOUN'), ('Boston', 'NOUN'), (',', '.'), ('Shearson', 'NOUN'), ('and', 'CONJ'), ('Drexel', 'NOUN'), ('Burnham', 'NOUN'), ('Lambert', 'NOUN'), ('Inc.', 'NOUN'), (',', '.'), ('in', 'ADP'), ('particular', 'ADJ'), (',', '.'), ('are', 'VERB'), ('likely', 'ADJ'), ('*-1', 'X'), ('to', 'PRT'), ('have', 'VERB'), ('difficulty', 'NOUN'), ('*-2', 'X'), ('shoring', 'VERB'), ('up', 'ADV'), ('their', 'PRON'), ('credit', 'NOUN'), ('standing', 'NOUN'), ('in', 'ADP'), ('months', 'NOUN'), ('ahead', 'ADV'), ('.', '.'), ('Also', 'ADV'), (',', '.'), ('Big', 'NOUN'), ('Board', 'NOUN'), ('Chairman', 'NOUN'), ('Phelan', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('he', 'PRON'), ('would', 'VERB'), ('support', 'VERB'), ('SEC', 'NOUN'), ('halts', 'NOUN'), ('of', 'ADP'), ('program', 'NOUN'), ('trading', 'NOUN'), ('during', 'ADP'), ('market', 'NOUN'), ('crises', 'NOUN'), ('but', 'CONJ'), ('not', 'ADV'), ('any', 'DET'), ('revival', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('``', '.'), ('collar', 'NOUN'), ("''", '.'), ('on', 'ADP'), ('trading', 'NOUN'), ('.', '.'), ('Columbia', 'NOUN'), ('Savings', 'NOUN'), ('&', 'CONJ'), ('Loan', 'NOUN'), ('-LRB-', '.'), ('NYSE', 'NOUN'), (';', '.'), ('Symbol', 'ADJ'), (':', '.'), ('CSV', 'NOUN'), ('-RRB-', '.'), ('I', 'PRON'), ('say', 'VERB'), ('``', '.'), ('*', 'X'), ('contained', 'VERB'), ('dialogue', 'NOUN'), ("''", '.'), ('because', 'ADP'), ('``', '.'), ('Sidewalk', 'NOUN'), ('Stories', 'NOUN'), ("''", '.'), ('is', 'VERB'), ("n't", 'ADV'), ('really', 'ADV'), ('silent', 'ADJ'), ('at', 'ADP'), ('all', 'DET'), ('.', '.'), ('In', 'ADP'), ('his', 'PRON'), ('return', 'VERB'), ('toast', 'NOUN'), ('to', 'PRT'), ('Mr.', 'NOUN'), ('Nixon', 'NOUN'), (',', '.'), ('Mr.', 'NOUN'), ('Yang', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('the', 'DET'), ('relationship', 'NOUN'), ('had', 'VERB'), ('reached', 'VERB'), ('a', 'DET'), ('``', '.'), ('stalemate', 'NOUN'), ('.', '.'), ("''", '.'), ('Municipal', 'NOUN'), ('bonds', 'NOUN'), ('were', 'VERB'), ('mostly', 'ADV'), ('unchanged', 'ADJ'), ('to', 'PRT'), ('up', 'ADV'), ('1\\/8', 'NUM'), ('point', 'NOUN'), ('in', 'ADP'), ('light', 'ADJ'), (',', '.'), ('cautious', ' ...

# %%
# accuracy
check_modified2 = [i for i, j in zip(tagged_seq_modified2, test_run_base) if i == j] 
accuracy_modified2 = len(check_modified2)/len(tagged_seq_modified2)
accuracy_modified2
# Out:
# 0.9443884747128752

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
# Accuracy with vanilla viterbi
accuracy_vanilla
# Out:
# 0.927664718920008

# %%
# Accuracy with vanilla viterbi with modification 1
accuracy_modified1
# Out:
# 0.9405601450735442

# %%
# Accuracy with vanilla viterbi with modification 2
accuracy_modified2
# Out:
# 0.9443884747128752

# %% [markdown]
# ### List down cases which were incorrectly tagged by original POS tagger and got corrected by your modifications

# %%
# Using the sample test sentense given in problem
sample_test_sentenses = ["Android is a mobile operating system developed by Google.",
                         "Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.",
                         "Google and Twitter made a deal in 2015 that gave Google access to Twitter's firehose.",
                         "Twitter is an online news and social networking service on which users post and interact with messages known as tweets.",
                         "Before entering politics, Donald Trump was a domineering businessman and a television personality.",
                         "The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.",
                         "This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.",
                         "Show me the cheapest round trips from Dallas to Atlanta",
                         "I would like to see flights from Denver to Philadelphia.",
                         "Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.",
                         "NASA invited social media users to experience the launch of ICESAT-2 Satellite."]
print(sample_test_sentenses)
# Out:
# ['Android is a mobile operating system developed by Google.', 'Android has been the best-selling OS worldwide on smartphones since 2011 and on tablets since 2013.', "Google and Twitter made a deal in 2015 that gave Google access to Twitter's firehose.", 'Twitter is an online news and social networking service on which users post and interact with messages known as tweets.', 'Before entering politics, Donald Trump was a domineering businessman and a television personality.', 'The 2018 FIFA World Cup is the 21st FIFA World Cup, an international football tournament contested once every four years.', 'This is the first World Cup to be held in Eastern Europe and the 11th time that it has been held in Europe.', 'Show me the cheapest round trips from Dallas to Atlanta', 'I would like to see flights from Denver to Philadelphia.', 'Show me the price of the flights leaving Atlanta at about 3 in the afternoon and arriving in San Francisco.', 'NASA invited social media users to experience the launch of ICESAT-2 Satellite.']

# %%
nltk.download('punkt')
sample_words = []
# # tokenize into words
tokenized_sents = [word_tokenize(i) for i in sample_test_sentenses]
for i in tokenized_sents:
    for k in i:
        sample_words.append(k)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amansrivasta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# tagging the sample sentences with vanilla viterbi
start = time.time()
tagged_seq = Viterbi(sample_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
print(tagged_seq)
# Out:
# Time taken in seconds:  35.65602254867554
# [('Android', 'ADJ'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'ADJ'), ('.', '.'), ('Android', 'ADJ'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'ADJ'), ('worldwide', 'ADJ'), ('on', 'ADP'), ('smartphones', 'ADJ'), ('since', 'ADP'), ('2011', 'ADJ'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'ADJ'), ('.', '.'), ('Google', 'ADJ'), ('and', 'CONJ'), ('Twitter', 'ADJ'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'ADJ'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'ADJ'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'ADJ'), ("'s", 'PRT'), ('firehose', 'ADJ'), ('.', '.'), ('Twitter', 'ADJ'), ('is', 'VERB'), ('an', 'DET'), ('online', 'ADJ'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'ADJ'), ('with', 'ADP'), ('messages', 'ADJ'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'ADJ'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'ADJ'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'ADJ'), ('.', '.'), ('The', 'DET'), ('2018', 'ADJ'), ('FIFA', 'ADJ'), ('World', 'NOUN'), ('Cup', 'ADJ'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'ADJ'), ('FIFA', 'ADJ'), ('World', 'NOUN'), ('Cup', 'ADJ'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'ADJ'), ('contested', 'ADJ'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'ADJ'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'ADJ'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'ADJ'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'ADJ'), ('invited', 'ADJ'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'ADJ'), ('Satellite', 'ADJ'), ('.', '.')]

# %%
# tagging the sample sentences with 2nd modified viterbi algo
start = time.time()
tagged_seq = Viterbi_modified2(sample_words)
end = time.time()
difference = end-start
print("Time taken in seconds: ", difference)
print(tagged_seq)
# Out:
# Time taken in seconds:  27.105536222457886
# [('Android', 'NOUN'), ('is', 'VERB'), ('a', 'DET'), ('mobile', 'ADJ'), ('operating', 'NOUN'), ('system', 'NOUN'), ('developed', 'VERB'), ('by', 'ADP'), ('Google', 'NOUN'), ('.', '.'), ('Android', 'NOUN'), ('has', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('best-selling', 'ADJ'), ('OS', 'NOUN'), ('worldwide', 'NOUN'), ('on', 'ADP'), ('smartphones', 'DET'), ('since', 'ADP'), ('2011', 'DET'), ('and', 'CONJ'), ('on', 'ADP'), ('tablets', 'NOUN'), ('since', 'ADP'), ('2013', 'DET'), ('.', '.'), ('Google', 'NOUN'), ('and', 'CONJ'), ('Twitter', 'NOUN'), ('made', 'VERB'), ('a', 'DET'), ('deal', 'NOUN'), ('in', 'ADP'), ('2015', 'DET'), ('that', 'ADP'), ('gave', 'VERB'), ('Google', 'NOUN'), ('access', 'NOUN'), ('to', 'PRT'), ('Twitter', 'NOUN'), ("'s", 'PRT'), ('firehose', 'VERB'), ('.', '.'), ('Twitter', 'NOUN'), ('is', 'VERB'), ('an', 'DET'), ('online', 'NOUN'), ('news', 'NOUN'), ('and', 'CONJ'), ('social', 'ADJ'), ('networking', 'NOUN'), ('service', 'NOUN'), ('on', 'ADP'), ('which', 'DET'), ('users', 'NOUN'), ('post', 'NOUN'), ('and', 'CONJ'), ('interact', 'NOUN'), ('with', 'ADP'), ('messages', 'NOUN'), ('known', 'VERB'), ('as', 'ADP'), ('tweets', 'DET'), ('.', '.'), ('Before', 'ADP'), ('entering', 'VERB'), ('politics', 'NOUN'), (',', '.'), ('Donald', 'NOUN'), ('Trump', 'NOUN'), ('was', 'VERB'), ('a', 'DET'), ('domineering', 'ADJ'), ('businessman', 'NOUN'), ('and', 'CONJ'), ('a', 'DET'), ('television', 'NOUN'), ('personality', 'ADJ'), ('.', '.'), ('The', 'DET'), ('2018', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('is', 'VERB'), ('the', 'DET'), ('21st', 'NOUN'), ('FIFA', 'NOUN'), ('World', 'NOUN'), ('Cup', 'NOUN'), (',', '.'), ('an', 'DET'), ('international', 'ADJ'), ('football', 'NOUN'), ('tournament', 'NOUN'), ('contested', 'NOUN'), ('once', 'ADV'), ('every', 'DET'), ('four', 'NUM'), ('years', 'NOUN'), ('.', '.'), ('This', 'DET'), ('is', 'VERB'), ('the', 'DET'), ('first', 'ADJ'), ('World', 'NOUN'), ('Cup', 'NOUN'), ('to', 'PRT'), ('be', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Eastern', 'NOUN'), ('Europe', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('11th', 'ADJ'), ('time', 'NOUN'), ('that', 'ADP'), ('it', 'PRON'), ('has', 'VERB'), ('been', 'VERB'), ('held', 'VERB'), ('in', 'ADP'), ('Europe', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('cheapest', 'ADJ'), ('round', 'NOUN'), ('trips', 'NOUN'), ('from', 'ADP'), ('Dallas', 'NOUN'), ('to', 'PRT'), ('Atlanta', 'NOUN'), ('I', 'PRON'), ('would', 'VERB'), ('like', 'ADP'), ('to', 'PRT'), ('see', 'VERB'), ('flights', 'NOUN'), ('from', 'ADP'), ('Denver', 'NOUN'), ('to', 'PRT'), ('Philadelphia', 'NOUN'), ('.', '.'), ('Show', 'NOUN'), ('me', 'PRON'), ('the', 'DET'), ('price', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('flights', 'NOUN'), ('leaving', 'VERB'), ('Atlanta', 'NOUN'), ('at', 'ADP'), ('about', 'ADP'), ('3', 'NUM'), ('in', 'ADP'), ('the', 'DET'), ('afternoon', 'NOUN'), ('and', 'CONJ'), ('arriving', 'VERB'), ('in', 'ADP'), ('San', 'NOUN'), ('Francisco', 'NOUN'), ('.', '.'), ('NASA', 'NOUN'), ('invited', 'VERB'), ('social', 'ADJ'), ('media', 'NOUN'), ('users', 'NOUN'), ('to', 'PRT'), ('experience', 'NOUN'), ('the', 'DET'), ('launch', 'NOUN'), ('of', 'ADP'), ('ICESAT-2', 'DET'), ('Satellite', 'NOUN'), ('.', '.')]

# %% [markdown]
# ## We can clearly see that Android, Google and Twitter were being tagged as 'CONJ' with the vanilla veterbi algo and with my modifications they are not correctly being tagged as 'NOUN'.
